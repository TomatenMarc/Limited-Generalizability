# %% [markdown]
# # Pull and create datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/Feger/limited-generalizability
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Feger/limited-generalizability

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.11/dist-packages (from en-core-web-lg==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import re
import os
import json
import spacy
import gzip
import pickle
import warnings
import pandas as pd
from tqdm.notebook import tqdm

warnings.simplefilter(action='ignore', category=FutureWarning)

nlp = spacy.load('en_core_web_lg')

ARGUMENT = "Argument"
NOARGUMENT = "No-Argument"

DSID_COL = "dataset_id"
TOPIC_COL = "topic"
SENTENCE_COL = "sentence"
LABEL_COL = "label"
DATASET_COL = "dataset"
DOMAIN_COL = "domain"
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %% [markdown]
# ## Helper Functions

# %%
def show_information(df):
    assert all(df[DSID_COL] == df[DSID_COL].unique())
    print(f"{df[DATASET_COL].unique()[0]} size:", df.shape[0])
    print("Topics:", len(df[TOPIC_COL].unique()))

# %%
def read_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

def read_json_data(file_path):
    with open(file_path, "r") as file:
        data = json.load(file)
    return data

def extract_sentences_spacy(text):
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]
    return sentences

def parse_annotations(annotation_lines):
    parsed_annotations = []
    for line in annotation_lines:
        parts = line.strip().split('\t')
        if len(parts) >= 3:
            tag_id = parts[0]
            tag_info = parts[1]
            tag_text = parts[2]
            tag_type, tag_start, tag_end = tag_info.split()
            parsed_annotations.append({
                'id': tag_id,
                'type': tag_type,
                'start': int(tag_start),
                'end': int(tag_end),
                'text': tag_text
            })
    return parsed_annotations

def match_annotations_to_sentences(text_content, annotations):
    sentences = extract_sentences_spacy(text_content)

    sentence_annotations = []
    for sentence in sentences:
        sentence_start = text_content.index(sentence)
        sentence_end = sentence_start + len(sentence)
        labels = [
            annotation for annotation in annotations
            if annotation['start'] >= sentence_start and annotation['end'] <= sentence_end
        ]
        sentence_annotations.append({
            'sentence': sentence,
            'labels': labels
        })
    return sentence_annotations

def prepare_output(sentence_annotations):
    output_data = []
    for entry in sentence_annotations:
        sentence = entry['sentence']
        labels = entry['labels']
        output_data.append({
            SENTENCE_COL: sentence.strip(),
            LABEL_COL: set([label['type'] for label in labels])
        })
    return output_data

def generate_label_positions(parsed_data):
    label_positions = []
    combined_text = ""
    current_position = 0

    for entry in parsed_data:
        label, sentence = entry['type'], entry['text']
        label_positions.append({
            'type': label,
            'start': current_position,
            'end': current_position + len(sentence),
            'text': sentence
        })
        combined_text += sentence + " "
        current_position += len(sentence) + 1

    return combined_text.strip(), label_positions

def parse_labeled_file(file_path):
    parsed_data = []
    content = read_file(file_path).splitlines()
    for line in content:
        parts = line.strip().split('\t')
        if len(parts) == 2:
            label, sentence = parts
            parsed_data.append({
                'type': label,
                'text': sentence
            })
    return parsed_data

# for .ann files that contian the entire text
def read_and_merge_annotations(file_path):
    merged_sentences = []
    labels = []
    current_sentence = ""
    current_labels = set()
    ending_symbols = ".?!"  # Define proper sentence-ending symbols
    parsed_lines = []

    # Step 1: Read and parse lines
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.split(maxsplit=4)
            if len(parts) < 5:
                continue
            tag_id, tag_type, tag_start, tag_end, tag_text = parts
            parsed_lines.append({
                'id': tag_id,
                'type': tag_type,
                'start': int(tag_start),
                'end': int(tag_end),
                'text': tag_text.strip()
            })

    # Step 2: Sort lines by start and end tags
    parsed_lines.sort(key=lambda x: (x['start'], x['end']))

    # Step 3: Apply merging rules
    for entry in parsed_lines:
        tag_text = entry['text']
        tag_type = entry['type']

        if current_sentence:
            next_starts_lower = tag_text[0].islower()
            next_starts_with_number = tag_text[0].isdigit()
            current_ends_semicolon = current_sentence[-1] == ";"
            current_not_ended = current_sentence[-1] not in ending_symbols

            # Concatenate if the current sentence ends with ; or is not properly ended and next starts with a number
            if current_ends_semicolon or (current_not_ended and (next_starts_lower or next_starts_with_number)):
                current_sentence += " " + tag_text
                current_labels.add(tag_type)
                continue

            # Add current completed sentence and its labels
            merged_sentences.append(current_sentence)
            labels.append(current_labels)  # Store labels as a set
            current_sentence = ""
            current_labels = set()

        # Start a new sentence
        current_sentence = tag_text
        current_labels.add(tag_type)

    # Append the final sentence and its labels
    if current_sentence:
        merged_sentences.append(current_sentence)
        labels.append(current_labels)

    # Create a DataFrame
    df = pd.DataFrame({
        SENTENCE_COL: merged_sentences,
        LABEL_COL: labels
    })
    return df

def split_into_sentences_custom(text):
    # Sometimes spacy is to slow for big documents.
    # Regex pattern to split on periods followed by a space or newlines, handling bullet points too
    sentence_endings = r'(?<=\.)\s+|\n+|\!|\?|\;'
    # Use regex to split based on the custom rule
    sentences = re.split(sentence_endings, text)
    # Clean sentences (strip extra spaces and remove empty ones)
    return [sentence.strip() for sentence in sentences]

def extract_and_label_sentences(data):
    sentences_with_labels = []
    argument_sentences = set()
    for document in tqdm(data):
        name = document['name']
        text = document['text']
        clauses = document['clauses']
        arguments = document['arguments']
        clause_id_to_span = {clause["_id"]: (clause["start"], clause["end"]) for clause in clauses}
        all_sentences = extract_sentences_spacy(text)
        for argument in arguments:
            conclusion_id = argument['conclusion']
            conclusion_start, conclusion_end = clause_id_to_span[conclusion_id]
            conclusion_sentence = text[conclusion_start:conclusion_end].strip()

            for sentence in all_sentences:
                if conclusion_sentence.lower() in sentence.strip().lower():
                    sentences_with_labels.append({DSID_COL: name, SENTENCE_COL: sentence.strip(), LABEL_COL: True})
                    argument_sentences.add(sentence.strip())

        for sentence in all_sentences:
            if sentence.strip() not in argument_sentences:
                sentences_with_labels.append({DSID_COL: name, SENTENCE_COL: sentence.strip(), LABEL_COL: False})

    return sentences_with_labels

# %% [markdown]
# ## Create data folder

# %%
! mkdir -p ./data

# %% [markdown]
# ## Create ASC

# %%
! wget https://github.com/RobinSchaefer/tweet-stance-classification/archive/refs/heads/master.zip
! mkdir -p ./data/ASC
! unzip -o master.zip -d ./data/ASC
! rm -r master.zip
! mv -f ./data/ASC/tweet-stance-classification-master/tsc/data/atheism_stance_corpus.json ./data/ASC
! rm -r ./data/ASC/tweet-stance-classification-master/
# Out:
# --2025-02-05 09:29:02--  https://github.com/RobinSchaefer/tweet-stance-classification/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/RobinSchaefer/tweet-stance-classification/zip/refs/heads/master [following]
# --2025-02-05 09:29:02--  https://codeload.github.com/RobinSchaefer/tweet-stance-classification/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              
#   inflating: ./data/ASC/tweet-stance-classification-master/tsc/lib/preprocessing.py
#    creating: ./data/ASC/tweet-stance-classification-master/tsc/scripts/
#   inflating: ./data/ASC/tweet-stance-classification-master/tsc/scripts/apply_tweet_tokenizer.py
#   inflating: ./data/ASC/tweet-stance-classification-master/tsc/scripts/convert_data_to_json.py
#   inflating: ./data/ASC/tweet-stance-classification-master/tsc/scripts/convert_json_to_txt.py

# %%
path = './data/ASC/'
final = 'asc.csv'
class2label = {'none': NOARGUMENT, 'against': NOARGUMENT, 'favor':  ARGUMENT}

asc = read_json_data("./data/ASC/atheism_stance_corpus.json")

data = []
for doc in asc:
    id = "ASC_" + str(doc["id"])
    sentence = doc["text"]
    label = doc["debateStancePolarity"]
    data.append((id, sentence, label))

df_asc = pd.DataFrame(data, columns=[DSID_COL, SENTENCE_COL, LABEL_COL])
assert df_asc.shape[0] == 715

df_asc[DATASET_COL] = "ASC"
df_asc[DOMAIN_COL] = "twitter.com"
df_asc[TOPIC_COL] = "random"
df_asc[LABEL_COL] = df_asc[LABEL_COL].replace(class2label)
df_asc = df_asc.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_asc = df_asc[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]

show_information(df_asc)
df_asc.to_csv(path + final, index=False)
# Out:
# ASC size: 715
# Topics: 1

# %%
# !rm ./data/ASC/atheism_stance_corpus.json

# %% [markdown]
# ## Create SDAT

# %%
! wget https://github.com/danielhers/sustainable-diet-arguments-twitter/archive/refs/heads/main.zip
! mkdir -p ./data/SDAT
! unzip -o main.zip -d ./data/SDAT
! mv -f ./data/SDAT/sustainable-diet-arguments-twitter-main/* ./data/SDAT
! rm -r main.zip
! rm -r ./data/SDAT/sustainable-diet-arguments-twitter-main
# Out:
# --2024-12-30 16:47:48--  https://github.com/danielhers/sustainable-diet-arguments-twitter/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/danielhers/sustainable-diet-arguments-twitter/zip/refs/heads/main [following]
# --2024-12-30 16:47:48--  https://codeload.github.com/danielhers/sustainable-diet-arguments-twitter/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [   <=>              ]   2.73M  5.26MB/s    in 0.5s
#
# 2024-12-30 16:47:49 (5.26 MB/s) - ‘main.zip’ saved [2862226]
#
# Archive:  main.zip
# 71559e7fcec80c5fc4e83d371a7c5bff78aa15d9
#    creating: ./data/SDAT/sustainable-diet-arguments-twitter-main/
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/.gitignore
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/Baseline.ipynb
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/README.md
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/Statistics.ipynb
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/Tweet-Scaper.ipynb
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/annotated-dataset.csv
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/baselines.py
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/credentials-example.json
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/scraped_tweets.csv
#   inflating: ./data/SDAT/sustainable-diet-arguments-twitter-main/utils.py

# %%
path = './data/SDAT/'
final = 'sdat.csv'
class2label = {True: ARGUMENT, False: NOARGUMENT}

df_sdat = pd.read_csv(path + 'annotated-dataset.csv')
df_sdat['id'] = df_sdat['id'].astype('int64')

for group in df_sdat.groupby('id'):
    argumentative = group[1].argumentative.values
    assert(all(argumentative == argumentative[0]))

df_sdat = df_sdat.drop_duplicates(subset='id')
df_sdat['argumentative'] = df_sdat['argumentative'] >= 0.5
df_sdat['argumentative'] = df_sdat['argumentative'].replace(class2label)


df_sdat[DOMAIN_COL] = 'https://twitter.com'
df_sdat = df_sdat[['id', 'domain', 'topic', 'argumentative', 'tweet']]
df_sdat[DATASET_COL] = 'SDAT'

df_sdat.rename(columns={
    "id": DSID_COL,
    "topic": TOPIC_COL,
    "argumentative": LABEL_COL,
    "tweet": SENTENCE_COL
}, inplace=True)

df_sdat = df_sdat[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
show_information(df_sdat)
df_sdat.to_csv(path + final, index=False)
# Out:
# SDAT size: 597
# Topics: 1

# %%
# !find ./data/SDAT -mindepth 1 -not -name 'sdat.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create SCIARK

# %%
# !git clone https://github.com/afergadis/SciARK.git
# !mkdir ./data/SCIARK
# !mv ./SciARK/dataset/SciARK.json ./data/SCIARK
# !rm -r ./SciARK
# Out:
# Cloning into 'SciARK'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 98 (delta 38), reused 95 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 4.17 MiB | 11.27 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (64/64), done.
# mkdir: cannot create directory ‘./data/SCIARK’: File exists

# %%
path = './data/SCIARK/'
final = 'sciark.csv'
class2label = {None: NOARGUMENT, 'Evidence': NOARGUMENT, 'Claim':  ARGUMENT}

sciark = read_json_data("./data/SCIARK/SciARK.json")
assert len(set(sciark.keys())) == 1000

data = []
for key in tqdm(sciark.keys()):
    doc = sciark[key]
    sentences = doc["sentences"]
    labels = doc["labels"]
    assert len(labels) == len(sentences)
    for line, (sentence, label) in list(enumerate(zip(sentences, labels))):
        data.append((key.split('.txt')[0] + "_" + str(line), sentence, label))

df_sciark = pd.DataFrame(data, columns=[DSID_COL, SENTENCE_COL, LABEL_COL])
assert df_sciark.shape[0] == 12374

df_sciark[DATASET_COL] = "SCIARK"
df_sciark[DOMAIN_COL] = "un.org"
df_sciark[TOPIC_COL] = "random"
df_sciark[LABEL_COL] = df_sciark[LABEL_COL].replace(class2label)
df_sciark = df_sciark.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_sciark = df_sciark[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]

show_information(df_sciark)
df_sciark.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# SCIARK size: 11695
# Topics: 1

# %%
# !find ./data/SCIARK -mindepth 1 -not -name 'sciark.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create AFS

# %%
# !wget http://nldslab.soe.ucsc.edu/afs16/Sigdial_16_release_data.zip
# !mkdir ./data/AFS
# !unzip Sigdial_16_release_data.zip -d ./data/AFS
# !mv ./data/AFS/server_data/ ./data/AFS/data
# !rm -r ./data/AFS/__MACOSX/
# !rm -r Sigdial_16_release_data.zip
# Out:
# --2024-12-29 15:47:37--  http://nldslab.soe.ucsc.edu/afs16/Sigdial_16_release_data.zip
# Resolving nldslab.soe.ucsc.edu (nldslab.soe.ucsc.edu)... 128.114.48.41
# Connecting to nldslab.soe.ucsc.edu (nldslab.soe.ucsc.edu)|128.114.48.41|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 775821 (758K) [application/zip]
# Saving to: ‘Sigdial_16_release_data.zip’
#
# Sigdial_16_release_ 100%[===================>] 757.64K  1.83MB/s    in 0.4s
#
# 2024-12-29 15:47:38 (1.83 MB/s) - ‘Sigdial_16_release_data.zip’ saved [775821/775821]
#
# mkdir: cannot create directory ‘./data/AFS’: File exists
# Archive:  Sigdial_16_release_data.zip
#    creating: ./data/AFS/server_data/
#   inflating: ./data/AFS/server_data/ArgPairs_DP.csv
#    creating: ./data/AFS/__MACOSX/
#    creating: ./data/AFS/__MACOSX/server_data/
#   inflating: ./data/AFS/__MACOSX/server_data/._ArgPairs_DP.csv
#   inflating: ./data/AFS/server_data/ArgPairs_GC.csv
#   inflating: ./data/AFS/__MACOSX/server_data/._ArgPairs_GC.csv
#   inflating: ./data/AFS/server_data/ArgPairs_GM.csv
#   inflating: ./data/AFS/__MACOSX/server_data/._ArgPairs_GM.csv
#   inflating: ./data/AFS/server_data/ArgQuality_DP.csv
#   inflating: ./data/AFS/__MACOSX/server_data/._ArgQuality_DP.csv
#   inflating: ./data/AFS/server_data/ArgQuality_GC.csv
#   inflating: ./data/AFS/__MACOSX/server_data/._ArgQuality_GC.csv
#   inflating: ./data/AFS/server_data/ArgQuality_GM.csv
#   inflating: ./data/AFS/__MACOSX/server_data/._ArgQuality_GM.csv

# %%
path = './data/AFS/'
final = 'afs.csv'
class2label = {True: ARGUMENT, False: NOARGUMENT}

df_q = pd.read_csv(path + 'data/ArgQuality_GC.csv', encoding='ISO-8859-1')
df_q[LABEL_COL] = df_q.apply(lambda row: True if row['Yes_Count'] > 3  else False, axis=1)
df_q[TOPIC_COL] = "Gun Control"
df_q[DSID_COL] = df_q[TOPIC_COL] + "_" + df_q["sentenceId"].astype(str) + "_" + df_q.index.astype(str)

df_d = pd.read_csv(path + 'data/ArgQuality_DP.csv', encoding='ISO-8859-1')
df_d[LABEL_COL] = df_d.apply(lambda row: True if row['scale3_Count'] > row['scale2_1_Count']  else False, axis=1)
df_d[TOPIC_COL] = "Death Penalty"
df_d[DSID_COL] = df_d[TOPIC_COL] + "_" + df_d["sentenceId"].astype(str) + "_" + df_d.index.astype(str)

df_g = pd.read_csv(path + 'data/ArgQuality_GM.csv', encoding='ISO-8859-1')
df_g[LABEL_COL] = df_g.apply(lambda row: True if row['Yes_Count'] > row['No_Count']  else False, axis=1)
df_g[TOPIC_COL] = "Gay Marriage"
df_g[DSID_COL] = df_g[TOPIC_COL] + "_" + df_g["sentenceId"].astype(str) + "_" + df_g.index.astype(str)

df_afs = pd.concat([df_q, df_d, df_g])

df_afs[DATASET_COL] = "AFS"
df_afs[DOMAIN_COL] = "procon.org + idebate.org"
df_afs[LABEL_COL] = df_afs[LABEL_COL].replace(class2label)
df_afs = df_afs.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_afs = df_afs[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]

show_information(df_afs)

df_afs.to_csv(path + final, index=False)
# Out:
# AFS size: 6186
# Topics: 3

# %%
# !find ./data/AFS -mindepth 1 -not -name 'afs.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create USELEC

# %%
# !git clone https://github.com/ElecDeb60To16/Dataset
# !mkdir ./data/USELEC
# !mv ./Dataset/sentence_db_candidate.csv ./data/USELEC
# !rm -r ./Dataset
# Out:
# Cloning into 'Dataset'...
# remote: Enumerating objects: 10, done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 10 (from 1)
# Receiving objects: 100% (10/10), 4.26 MiB | 10.58 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# mkdir: cannot create directory ‘./data/USELEC’: File exists

# %%
path = './data/USELEC/'
final = 'uselec.csv'
class2label = {True: ARGUMENT, False: NOARGUMENT}


df_uselec = pd.read_csv(path + "sentence_db_candidate.csv")
df_uselec['Tag'] = df_uselec['Tag'].apply(lambda x: eval(x) if isinstance(x, str) else x)
df_uselec[LABEL_COL] = df_uselec['Tag'].apply(lambda x: 'Claim' in x if isinstance(x, dict) else False)

df_uselec[DATASET_COL] = "USELEC"
df_uselec[DOMAIN_COL] = "debates.org"
df_uselec[LABEL_COL] = df_uselec[LABEL_COL].replace(class2label)
df_uselec[DSID_COL] = df_uselec["Document"] + "_" + df_uselec["Sentence"].astype(str) + "_" + df_uselec.index.astype(str)
df_uselec[TOPIC_COL] = df_uselec["Speaker"]
df_uselec[SENTENCE_COL] = df_uselec["Text"]

df_uselec = df_uselec.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_uselec = df_uselec[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]

show_information(df_uselec)

df_uselec.to_csv(path + final, index=False)
# Out:
# USELEC size: 29093
# Topics: 29

# %%
# !find ./data/USELEC -mindepth 1 -not -name 'uselec.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create ECHR

# %%
# !wget http://www.di.uevora.pt/~pq/echr/echr_corpus.zip
# !mkdir ./data/ECHR
# !unzip ./echr_corpus.zip -d ./data/ECHR
# !mv ./data/ECHR/echr_corpus/ ./data/ECHR/data
# !rm -r ./data/ECHR/__MACOSX
# !rm -r echr_corpus.zip
# Out:
# --2024-12-29 15:41:06--  http://www.di.uevora.pt/~pq/echr/echr_corpus.zip
# Resolving www.di.uevora.pt (www.di.uevora.pt)... 193.137.179.82
# Connecting to www.di.uevora.pt (www.di.uevora.pt)|193.137.179.82|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 749759 (732K) [application/zip]
# Saving to: ‘echr_corpus.zip’
#
# echr_corpus.zip     100%[===================>] 732.19K   483KB/s    in 1.5s
#
# 2024-12-29 15:41:08 (483 KB/s) - ‘echr_corpus.zip’ saved [749759/749759]
#
# mkdir: cannot create directory ‘./data/ECHR’: File exists
# Archive:  ./echr_corpus.zip
#    creating: ./data/ECHR/echr_corpus/
#   inflating: ./data/ECHR/echr_corpus/.DS_Store
#    creating: ./data/ECHR/__MACOSX/
#    creating: ./data/ECHR/__MACOSX/echr_corpus/
#   inflating: ./data/ECHR/__MACOSX/echr_corpus/._.DS_Store
#   inflating: ./data/ECHR/echr_corpus/ECHR_Corpus.json
#   inflating: ./data/ECHR/__MACOSX/echr_corpus/._ECHR_Corpus.json

# %%
path = './data/ECHR/'
final = 'echr.csv'
class2label = {True: ARGUMENT, False: NOARGUMENT}

file_path = path + 'data/ECHR_Corpus.json'
data = read_json_data(file_path)
sentences_with_labels = extract_and_label_sentences(data)

df_echr = pd.DataFrame(sentences_with_labels, columns=[DSID_COL, SENTENCE_COL, LABEL_COL])
df_echr[DATASET_COL] = "ECHR"
df_echr[DOMAIN_COL] = "hudoc.echr.coe.int"
df_echr[LABEL_COL] = df_echr[LABEL_COL].replace(class2label)
df_echr[DSID_COL] = df_echr[DSID_COL].str.split(".txt").str[0] + "_" + df_echr.index.astype(str)
df_echr[TOPIC_COL] = "random"

df_echr = df_echr.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_echr = df_echr[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
show_information(df_echr)

df_echr.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# ECHR size: 10678
# Topics: 1

# %%
# !find ./data/ECHR -mindepth 1 -not -name 'echr.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create CE

# %%
# !wget https://www.research.ibm.com/haifa/dept/vst/files/IBM_Debater_\(R\)_CE-EMNLP-2015.v3.zip
# !mkdir ./data/CE/data
# !unzip IBM_Debater_\(R\)_CE-EMNLP-2015.v3.zip -d ./data/CE
# !mv ./data/CE/IBM_Debater_\(R\)_CE-EMNLP-2015.v3/claims.txt ./data/CE/data/
# !mv ./data/CE/IBM_Debater_\(R\)_CE-EMNLP-2015.v3/articles.txt ./data/CE/data/
# !unzip ./data/CE/IBM_Debater_\(R\)_CE-EMNLP-2015.v3/articles.zip -d ./data/CE/data
# !rm -r ./data/CE/IBM_Debater_\(R\)_CE-EMNLP-2015.v3
# !rm -r ./IBM_Debater_\(R\)_CE-EMNLP-2015.v3.zip
# Out:
# --2024-12-29 15:27:16--  https://www.research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_CE-EMNLP-2015.v3.zip
# Resolving www.research.ibm.com (www.research.ibm.com)... 13.32.230.22, 13.32.230.29, 13.32.230.125, ...
# Connecting to www.research.ibm.com (www.research.ibm.com)|13.32.230.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_CE-EMNLP-2015.v3.zip [following]
# --2024-12-29 15:27:16--  https://research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_CE-EMNLP-2015.v3.zip
# Resolving research.ibm.com (research.ibm.com)... 108.138.106.127, 108.138.106.96, 108.138.106.72, ...
# Connecting to research.ibm.com (research.ibm.com)|108.138.106.127|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9058276 (8.6M) [application/zip]
# Saving to: ‘IBM_Debater_(R)_CE-EMNLP-2015.v3.zip’
#
# IBM_Debater_(R)_CE- 100%[===================>]   8.64M  4.35MB/s    in 2.0s
#
# 2024-12-29 15:27:19 (4.35 MB/s) - ‘IBM_Debater_(R)_CE-EMNLP-2015.v3.zip’ saved [9058276/9058276]
#
# Archive:  IBM_Debater_(R)_CE-EMNLP-2015.v3.zip
#    creating: ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/
#   inflating: ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/articles.txt
#   inflating: ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/articles.zip
#   inflating: ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/claims.txt
#   inflating: ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/evidence.txt
#   inflating: ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/motions.txt
#   inflating: ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/README.txt
# Archive:  ./data/CE/IBM_Debater_(R)_CE-EMNLP-2015.v3/articles.zip
#    creating: ./data/CE/data/articles/
#   inflating: ./data/CE/data/articles/clean_1.txt
#   inflating: ./data/CE/data/articles/clean_1000.txt
#   inflating: ./data/CE/data/articles/clean_1001.txt
#   inflating: ./data/CE/data/articles/clean_101.txt
#   inflating: ./data/CE/data/articles/clean_1029.txt
#   inflating: ./data/CE/data/articles/clean_1030.txt
#   inflating: ./data/CE/data/articles/clean_1031.txt
#   inflating: ./data/CE/data/articles/clean_1032.txt
#   inflating: ./data/CE/data/articles/clean_1033.txt
#   inflating: ./data/CE/data/articles/clean_1034.txt
#   inflating: ./data/CE/data/articles/clean_1035.txt
#   inflating: ./data/CE/data/articles/clean_1036.txt
#   inflating: ./data/CE/data/articles/clean_1037.txt
#   inflating: ./data/CE/data/articles/clean_1063.txt
#   inflating: ./data/CE/data/articles/clean_1064.txt
#   inflating: ./data/CE/data/articles/clean_1065.txt
#   inflating: ./data/CE/data/articles/clean_1066.txt
#   inflating: ./data/CE/data/articles/clean_1079.txt
#   inflating: ./data/CE/data/articles/clean_1080.txt
ids = sorted(set([int(f.split(".txt")[0].split("_")[-1]) for f in os.listdir(path + "data/articles")]))
df_claims = pd.read_csv("./data/CE/data/claims.txt", sep="\t")

assert df_articles["article Id"].isin(ids).all()
assert df_articles["Topic"].isin(df_claims["Topic"]).all()
assert df_claims["Topic"].isin(df_articles["Topic"]).all()

ids = [id for id in ids if id in df_articles["article Id"].values]

df_ce = pd.DataFrame()

# Initialize a list to store sentences
sentences = []
# Loop through all files in the specified directory
for id in tqdm(ids):
    file_path = path + f"data/articles/clean_{id}.txt"
    text = read_file(file_path)
    # Split the text into sentences and add file ID
    for sentence in split_into_sentences_custom(text):
        sentences.append((sentence, id))
# Read claims file and split it into a list of claims (with each claim as a list of strings)
claims = df_claims.values
annotated_data = []
# Loop through the sentences and claims
for sentence, file_id in tqdm(sentences):
    match_found = False
    for claim in claims:
        if claim[1].lower() in sentence.lower():
            match_found = True
            break  # Exit the loop as we found a match, no need to check further claims for this sentence
    annotated_data.append((file_id, sentence, match_found, file_id))

df_ce = pd.DataFrame(annotated_data, columns=[TOPIC_COL, SENTENCE_COL, LABEL_COL, DSID_COL])
df_ce[DATASET_COL] = "CE"
df_ce[DOMAIN_COL] = "wikipedia.org"
df_ce[LABEL_COL] = df_ce[LABEL_COL].replace(class2label)
df_ce[DSID_COL] = df_ce[DSID_COL].astype(str) + "_" + df_ce.index.astype(str)
df_ce[TOPIC_COL] = df_ce[TOPIC_COL].map(df_articles.set_index("article Id")["Topic"])

df_ce = df_ce.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_ce = df_ce[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
show_information(df_ce)

df_ce.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/547 [00:00<?, ?it/s]
#   0%|          | 0/97324 [00:00<?, ?it/s]
# CE size: 86964
# Topics: 58

# %%
# !find ./data/CE -mindepth 1 -not -name 'ce.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create ARGUMINSCI

# %%
# !wget http://data.dws.informatik.uni-mannheim.de/sci-arg/compiled_corpus.zip
# !mkdir ./data/ARGUMINSCI
# !unzip compiled_corpus.zip -d ./data/ARGUMINSCI
# !mv ./data/ARGUMINSCI/compiled_corpus/ ./data/ARGUMINSCI/data
# !rm -r ./compiled_corpus.zip
# Out:
# --2024-12-29 15:24:04--  http://data.dws.informatik.uni-mannheim.de/sci-arg/compiled_corpus.zip
# Resolving data.dws.informatik.uni-mannheim.de (data.dws.informatik.uni-mannheim.de)... 134.155.95.56
# Connecting to data.dws.informatik.uni-mannheim.de (data.dws.informatik.uni-mannheim.de)|134.155.95.56|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.dws.informatik.uni-mannheim.de/sci-arg/compiled_corpus.zip [following]
# --2024-12-29 15:24:05--  https://data.dws.informatik.uni-mannheim.de/sci-arg/compiled_corpus.zip
# Connecting to data.dws.informatik.uni-mannheim.de (data.dws.informatik.uni-mannheim.de)|134.155.95.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1129621 (1.1M) [application/zip]
# Saving to: ‘compiled_corpus.zip’
#
# compiled_corpus.zip 100%[===================>]   1.08M  2.06MB/s    in 0.5s
#
# 2024-12-29 15:24:06 (2.06 MB/s) - ‘compiled_corpus.zip’ saved [1129621/1129621]
#
# mkdir: cannot create directory ‘./data/ARGUMINSCI’: File exists
# Archive:  compiled_corpus.zip
#    creating: ./data/ARGUMINSCI/compiled_corpus/
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A01.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A01.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A02.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A02.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A03.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A03.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A04.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A04.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A05.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A05.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A06.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A06.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A07.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A07.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A08.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A08.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A09.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A09.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A10.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A10.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A11.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A11.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A12.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A12.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A13.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A13.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A14.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A14.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A15.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A15.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A16.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A16.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A17.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A17.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A18.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A18.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A19.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A19.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A20.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A20.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A21.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A21.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A22.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A22.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A23.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A23.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A24.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A24.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A25.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A25.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A26.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A26.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A27.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A27.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A28.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A28.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A29.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A29.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A30.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A30.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A31.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A31.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A32.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A32.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A33.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A33.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A34.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A34.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A35.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A35.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A36.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A36.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A37.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A37.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A38.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A38.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A39.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A39.txt
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A40.ann
#   inflating: ./data/ARGUMINSCI/compiled_corpus/A40.txt

# %%
path = './data/ARGUMINSCI/'
final = 'arguminsci.csv'

df_arguminsci = pd.DataFrame()

for f in tqdm(set([f.split(".")[0] for f in os.listdir(path + "data")])):
    # Load and process files
    txt_path = path + f"data/{f}.txt"
    ann_path = path + f"data/{f}.ann"
    text_content = read_file(txt_path)
    annotation_lines = read_file(ann_path).splitlines()
    annotation_lines = [line for line in annotation_lines if line.startswith('T')] # Keep text labels
    annotation_lines = [line for line in annotation_lines if not ";" in line.split("\t")[1]] # remove lines with error

    parsed_annotations = parse_annotations(annotation_lines)
    # Match annotations to sentences
    sentence_annotations = match_annotations_to_sentences(text_content, parsed_annotations)
    # Prepare data for display
    output_data = prepare_output(sentence_annotations)
    # Create a DataFrame
    output_df = pd.DataFrame(output_data)
    output_df[DSID_COL] = output_df.apply(lambda row: f + "_" + str(row.name), axis=1)

    df_arguminsci = pd.concat([df_arguminsci, output_df])

df_arguminsci[LABEL_COL] = df_arguminsci[LABEL_COL].apply(lambda row: any("claim" in label.lower() for label in row))
df_arguminsci[LABEL_COL] = df_arguminsci[LABEL_COL].replace({True: ARGUMENT, False: NOARGUMENT})

df_arguminsci[DATASET_COL] = "ARGUMINSCI"
df_arguminsci[DOMAIN_COL] = "Dr. Inventor"
df_arguminsci[TOPIC_COL] = "random"

df_arguminsci = df_arguminsci.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_arguminsci = df_arguminsci[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
show_information(df_arguminsci)

df_arguminsci.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# ARGUMINSCI size: 16102
# Topics: 1

# %%
# !find ./data/ARGUMINSCI -mindepth 1 -not -name 'arguminsci.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create CMV

# %%
# !git clone https://github.com/chridey/change-my-view-modes.git
# !mkdir ./data/CMV/
# !mv change-my-view-modes/v2.0/negative ./data/CMV
# !mv change-my-view-modes/v2.0/positive ./data/CMV
# !rm -r ./change-my-view-modes
# Out:
# Cloning into 'change-my-view-modes'...
# remote: Enumerating objects: 1482, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 1482 (delta 3), reused 3 (delta 0), pack-reused 1458 (from 1)
# Receiving objects: 100% (1482/1482), 1.27 MiB | 6.87 MiB/s, done.
# Resolving deltas: 100% (919/919), done.
# Updating files: 100% (739/739), done.
# mkdir: cannot create directory ‘./data/CMV/’: File exists

# %%
path = './data/CMV/'
final = 'cmv.csv'

df_cmv = pd.DataFrame()

for d in tqdm(["positive", "negative"]):
    for f in tqdm(set([f.split(".")[0] for f in os.listdir(path + d)])):
        # Load and process files
        txt_path = path + f"{d}/{f}.txt"
        ann_path = path + f"{d}/{f}.ann"
        text_content = read_file(txt_path)
        annotation_lines = read_file(ann_path).splitlines()
        # Parse annotations
        parsed_annotations = parse_annotations(annotation_lines)
        # Match annotations to sentences
        sentence_annotations = match_annotations_to_sentences(text_content, parsed_annotations)
        # Prepare data for display
        output_data = prepare_output(sentence_annotations)
        # Create a DataFrame
        output_df = pd.DataFrame(output_data)
        output_df[DSID_COL] = d[0] + "_" + f + "_" + output_df.index.astype(str)
        df_cmv = pd.concat([df_cmv, output_df])

df_cmv[LABEL_COL] = df_cmv[LABEL_COL].apply(lambda row: any("claim" in label.lower() for label in row))
df_cmv[LABEL_COL] = df_cmv[LABEL_COL].replace({True: ARGUMENT, False: NOARGUMENT})

df_cmv[TOPIC_COL] = "random"
df_cmv[DATASET_COL] = "CMV"
df_cmv[DOMAIN_COL] = "reddit.com/r/changemyview/"

df_cmv = df_cmv.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_cmv = df_cmv[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_cmv = df_cmv[~df_cmv[DSID_COL].duplicated()]
show_information(df_cmv)

df_cmv.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/49 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# CMV size: 2572
# Topics: 1

# %%
# !find ./data/CMV -mindepth 1 -not -name 'cmv.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create VACC

# %%
# !git clone https://github.com/cltl/vaccination-corpus.git
# !cp vaccination-corpus/code/conll_data.py ./
# !mkdir -p ./data/VACC
# !mv ./vaccination-corpus/data/annotations-pickle ./data/VACC/
# !mv ./data/VACC/annotations-pickle/ ./data/VACC/data/
# !rm -r ./vaccination-corpus
# Out:
# Cloning into 'vaccination-corpus'...
# remote: Enumerating objects: 3145, done.
# remote: Counting objects: 100% (353/353), done.
# remote: Compressing objects: 100% (346/346), done.
# remote: Total 3145 (delta 29), reused 314 (delta 7), pack-reused 2792 (from 1)
# Receiving objects: 100% (3145/3145), 116.84 MiB | 13.21 MiB/s, done.
# Resolving deltas: 100% (1622/1622), done.
# Updating files: 100% (1824/1824), done.

# %%
path = "./data/VACC/"
final = "vacc.csv"

class2label = {True: ARGUMENT, False: NOARGUMENT}
df_vacc = pd.DataFrame()

annotations = list()
for pickle_file in tqdm(os.listdir(path + "data/")):
    with gzip.open(path + "data/" + pickle_file, "rb") as infile:
        topic = pickle_file.split("/")[-1].split("_")[0]
        doc = pickle.load(infile)
        claim_sentence_ids = list()
        for claim in doc.claims:
            for sent_id, token_id in claim.sent_token_ids:
                claim_sentence_ids.append(sent_id)
        for sentence in doc.sentences:
            annotations.append((topic, sentence.id, sentence.text, sentence.sent_id in claim_sentence_ids))

df_vacc = pd.DataFrame(annotations, columns=[TOPIC_COL, DSID_COL, SENTENCE_COL, LABEL_COL])
df_vacc[DATASET_COL] = "VACC"
df_vacc[DOMAIN_COL] = "random"
df_vacc[LABEL_COL] = df_vacc[LABEL_COL].replace(class2label)
df_vacc = df_vacc[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_vacc = df_vacc.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_vacc)
df_vacc.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/294 [00:00<?, ?it/s]
# VACC size: 22219
# Topics: 177

# %%
# !find ./data/VACC -mindepth 1 -not -name 'vacc.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \
#   inflating: ./data/WTP/data/WTP/001.train
#   inflating: ./data/WTP/data/WTP/001.dev
#   inflating: ./data/WTP/data/WTP/004.dev
#   inflating: ./data/WTP/data/WTP/010.dev
#   inflating: ./data/WTP/data/WTP/005.train
#   inflating: ./data/WTP/data/WTP/005.dev
#   inflating: ./data/WTP/data/WTP/007.dev
#   inflating: ./data/WTP/data/WTP/001.test
#   inflating: ./data/WTP/data/WTP/007.train
#   inflating: ./data/WTP/data/WTP/006.dev
#   inflating: ./data/WTP/data/README.md
#   inflating: ./data/WTP/data/__MACOSX/._README.md

# %%
path = "./data/WTP/"
final = "wtp.csv"

class2label = {1: ARGUMENT, 0: NOARGUMENT}
df_wtp = pd.DataFrame()

for f in os.listdir(path + "data/WTP"):
    if not (f.endswith(".train") or f.endswith(".dev") or f.endswith(".test")):
        continue
    data = []
    content = read_file(path + f"data/WTP/{f}")
    for line in content.splitlines():
        sentence, label = line.split("\t")
        data.append((sentence.strip(), int(label)))

    df = pd.DataFrame(data, columns=[SENTENCE_COL, LABEL_COL])
    df[DSID_COL] = df.apply(lambda row: f.replace('.', '_') + "_" + str(row.name), axis=1)
    df_wtp = pd.concat([df_wtp, df])

df_wtp[LABEL_COL] = df_wtp[LABEL_COL].replace(class2label)
df_wtp[TOPIC_COL] = "random"
df_wtp[DATASET_COL] = "WTP"
df_wtp[DOMAIN_COL] = "wikipedia.com"
df_wtp[DSID_COL] = df_wtp[DATASET_COL] + "_" + df_wtp[DSID_COL]
df_wtp = df_wtp.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_wtp = df_wtp[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
show_information(df_wtp)
df_wtp.to_csv(path + final, index=False)
# Out:
# WTP size: 8410
# Topics: 1

# %%
# !find ./data/WTP -mindepth 1 -not -name 'wtp.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create OC

# %%
! git clone https://github.com/UKPLab/emnlp2017-claim-identification.git
! mkdir ./data/OC
! unzip ./emnlp2017-claim-identification/src/main/python/data.zip -d ./data/OC/data
! rm -r ./emnlp2017-claim-identification
# Out:
# Cloning into 'emnlp2017-claim-identification'...
# remote: Enumerating objects: 328, done.
# remote: Total 328 (delta 0), reused 0 (delta 0), pack-reused 328 (from 1)
# Receiving objects: 100% (328/328), 12.56 MiB | 11.22 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# Updating files: 100% (138/138), done.
# mkdir: cannot create directory ‘./data/OC’: File exists
# Archive:  ./emnlp2017-claim-identification/src/main/python/data.zip
#    creating: ./data/OC/data/PE/
#   inflating: ./data/OC/data/PE/002.test
#   inflating: ./data/OC/data/PE/008.dev
#   inflating: ./data/OC/data/PE/009.train
#   inflating: ./data/OC/data/PE/009.dev
#   inflating: ./data/OC/data/PE/010.train
#   inflating: ./data/OC/data/PE/003.test
#   inflating: ./data/OC/data/PE/008.train
#   inflating: ./data/OC/data/PE/008.test
#   inflating: ./data/OC/data/PE/004.test
#   inflating: ./data/OC/data/PE/005.test
#   inflating: ./data/OC/data/PE/009.test
#   inflating: ./data/OC/data/PE/006.test
#   inflating: ./data/OC/data/PE/002.train
#   inflating: ./data/OC/data/PE/010.test
#   inflating: ./data/OC/data/PE/006.train
#   inflating: ./data/OC/data/PE/007.test
#   inflating: ./data/OC/data/WD/005.dev
#   inflating: ./data/OC/data/WD/007.dev
#   inflating: ./data/OC/data/WD/001.test
#   inflating: ./data/OC/data/WD/007.train
#   inflating: ./data/OC/data/WD/006.dev
#    creating: ./data/OC/data/WTP/
#   inflating: ./data/OC/data/WTP/002.test
#   inflating: ./data/OC/data/WTP/008.dev
#   inflating: ./data/OC/data/WTP/009.train
#   inflating: ./data/OC/data/WTP/009.dev
#   inflating: ./data/OC/data/WTP/010.train
#   inflating: ./data/OC/data/WTP/003.test
#   inflating: ./data/OC/data/WTP/008.train
#   inflating: ./data/OC/data/WTP/008.test
#   inflating: ./data/OC/data/WTP/004.test
#   inflating: ./data/OC/data/WTP/005.test
#   inflating: ./data/OC/data/WTP/009.test
#   inflating: ./data/OC/data/WTP/006.test
#   inflating: ./data/OC/data/WTP/002.train
#   inflating: ./data/OC/data/WTP/010.test
#   inflating: ./data/OC/data/WTP/006.train
#   inflating: ./data/OC/data/WTP/007.test
#   inflating: ./data/OC/data/WTP/004.train
#   inflating: ./data/OC/data/WTP/002.dev
#   inflating: ./data/OC/data/WTP/003.dev
#   inflating: ./data/OC/data/WTP/003.train
#   inflating: ./data/OC/data/WTP/001.train
#   inflating: ./data/OC/data/WTP/001.dev
#   inflating: ./data/OC/data/WTP/004.dev
#   inflating: ./data/OC/data/WTP/010.dev
#   inflating: ./data/OC/data/WTP/005.train
#   inflating: ./data/OC/data/WTP/005.dev
#   inflating: ./data/OC/data/WTP/007.dev
#   inflating: ./data/OC/data/WTP/001.test
#   inflating: ./data/OC/data/WTP/007.train
#   inflating: ./data/OC/data/WTP/006.dev
#   inflating: ./data/OC/data/README.md
#   inflating: ./data/OC/data/__MACOSX/._README.md

# %%
path = "./data/OC/"
final = "oc.csv"

class2label = {1: ARGUMENT, 0: NOARGUMENT}
df_oc = pd.DataFrame()

for f in os.listdir(path + "data/OC"):
    if not (f.endswith(".train") or f.endswith(".dev") or f.endswith(".test")):
        continue
    data = []
    content = read_file(path + f"data/OC/{f}")
    for line in content.splitlines():
        sentence, label = line.split("\t")
        data.append((sentence.strip(), int(label)))

    df = pd.DataFrame(data, columns=[SENTENCE_COL, LABEL_COL])
    df[DSID_COL] = df.apply(lambda row: f.replace('.', '_') + "_" + str(row.name), axis=1)
    df_oc = pd.concat([df_oc, df])

df_oc[LABEL_COL] = df_oc[LABEL_COL].replace(class2label)
df_oc[TOPIC_COL] = "random"
df_oc[DATASET_COL] = "OC"
df_oc[DOMAIN_COL] = "livejournal.com"
df_oc[DSID_COL] = df_oc[DATASET_COL] + "_" + df_oc[DSID_COL]
df_oc = df_oc.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_oc = df_oc[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_oc = df_oc[df_oc['sentence'] != "\ufeff"]
show_information(df_oc)
df_oc.to_csv(path + final, index=False)
# Out:
# OC size: 8527
# Topics: 1

# %%
# !find ./data/OC -mindepth 1 -not -name 'oc.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ##
class2label = {1: ARGUMENT, 0: NOARGUMENT}
df_pe = pd.DataFrame()

for f in os.listdir(path + "data/PE"):
    if not (f.endswith(".train") or f.endswith(".dev") or f.endswith(".test")):
        continue
    data = []
    content = read_file(path + f"data/PE/{f}")
    for line in content.splitlines():
        sentence, label = line.split("\t")
        data.append((sentence.strip(), int(label)))

    df = pd.DataFrame(data, columns=[SENTENCE_COL, LABEL_COL])
    df[DSID_COL] = df.apply(lambda row: f.replace('.', '_') + "_" + str(row.name), axis=1)
    df_pe = pd.concat([df_pe, df])

df_pe[LABEL_COL] = df_pe[LABEL_COL].replace(class2label)
df_pe[TOPIC_COL] = "random"
df_pe[DATASET_COL] = "PE"
df_pe[DOMAIN_COL] = "essayforum.com"
df_pe[DSID_COL] = df_pe[DATASET_COL] + "_" + df_pe[DSID_COL]
df_pe = df_pe.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_pe = df_pe[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
show_information(df_pe)
df_pe.to_csv(path + final, index=False)
# Out:
# PE size: 7051
# Topics: 1

# %%
# !find ./data/PE -mindepth 1 -not -name 'pe.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create MT

# %%
! git clone https://github.com/UKPLab/emnlp2017-claim-identification.git
! mkdir ./data/MT
! unzip ./emnlp2017-claim-identification/src/main/python/data.zip -d ./data/MT/data
! rm -r ./emnlp2017-claim-identification
# Out:
# Cloning into 'emnlp2017-claim-identification'...
# remote: Enumerating objects: 328, done.
# remote: Total 328 (delta 0), reused 0 (delta 0), pack-reused 328 (from 1)
# Receiving objects: 100% (328/328), 12.56 MiB | 15.35 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# Updating files: 100% (138/138), done.
# mkdir: cannot create directory ‘./data/MT’: File exists
# Archive:  ./emnlp2017-claim-identification/src/main/python/data.zip
#    creating: ./data/MT/data/PE/
#   inflating: ./data/MT/data/PE/002.test
#   inflating: ./data/MT/data/PE/008.dev
#   inflating: ./data/MT/data/PE/009.train
#   inflating: ./data/MT/data/PE/009.dev
#   inflating: ./data/MT/data/PE/010.train
#   inflating: ./data/MT/data/PE/003.test
#   inflating: ./data/MT/data/PE/008.train
#   inflating: ./data/MT/data/PE/008.test
#   inflating: ./data/MT/data/PE/004.test
#   inflating: ./data/MT/data/PE/005.test
#   inflating: ./data/MT/data/PE/009.test
#   inflating: ./data/MT/data/PE/006.test
#   inflating: ./data/MT/data/PE/002.train
#   inflating: ./data/MT/data/PE/010.test
#   inflating: ./data/MT/data/PE/006.train
#   inflating: ./data/MT/data/PE/007.test
#   inflating: ./data/MT/data/PE/004.train
#   inflating: ./data/MT/data/PE/002.dev
#   inflating: ./data/MT/data/PE/003.dev
#   inflating: ./data/MT/data/PE/003.train
#   inflating: ./data/MT/data/PE/001.train
#   inflating: ./data/MT/data/PE/001.dev
#   inflating: ./data/MT/data/PE/004.dev
#   inflating: ./data/MT/data/PE/010.dev
#   inflating: ./data/MT/data/PE/005.train
#   inflating: ./data/MT/data/PE/005.dev
#   inflating: ./data/MT/data/PE/007.dev
#   inflating: ./data/MT/data/PE/001.test
#   inflating: ./data/MT/data/PE/007.train
#   inflating: ./data/MT/data/PE/006.dev
#    creating: ./data/MT/data/VG/
#   inflating: ./data/MT/data/WTP/005.test
#   inflating: ./data/MT/data/WTP/009.test
#   inflating: ./data/MT/data/WTP/006.test
#   inflating: ./data/MT/data/WTP/002.train
#   inflating: ./data/MT/data/WTP/010.test
#   inflating: ./data/MT/data/WTP/006.train
#   inflating: ./data/MT/data/WTP/007.test
#   inflating: ./data/MT/data/WTP/004.train
#   inflating: ./data/MT/data/WTP/002.dev
#   inflating: ./data/MT/data/WTP/003.dev
#   inflating: ./data/MT/data/WTP/003.train
#   inflating: ./data/MT/data/WTP/001.train
#   inflating: ./data/MT/data/WTP/001.dev
#   inflating: ./data/MT/data/WTP/004.dev
#   inflating: ./data/MT/data/WTP/010.dev
#   inflating: ./data/MT/data/WTP/005.train
#   inflating: ./data/MT/data/WTP/005.dev
#   inflating: ./data/MT/data/WTP/007.dev
#   inflating: ./data/MT/data/WTP/001.test
#   inflating: ./data/MT/data/WTP/007.train
#   inflating: ./data/MT/data/WTP/006.dev
#   inflating: ./data/MT/data/README.md
#   inflating: ./data/MT/data/__MACOSX/._README.md

# %%
path = "./data/MT/"
final = "mt.csv"

class2label = {1: ARGUMENT, 0: NOARGUMENT}
df_mt = pd.DataFrame()

for f in os.listdir(path + "data/MT"):
    if not (f.endswith(".train") or f.endswith(".dev") or f.endswith(".test")):
        continue
    data = []
    content = read_file(path + f"data/MT/{f}")
    for line in content.splitlines():
        sentence, label = line.split("\t")
        data.append((sentence.strip(), int(label)))

    df = pd.DataFrame(data, columns=[SENTENCE_COL, LABEL_COL])
    df[DSID_COL] = df.apply(lambda row: f.replace('.', '_') + "_" + str(row.name), axis=1)
    df_mt = pd.concat([df_mt, df])

df_mt[LABEL_COL] = df_mt[LABEL_COL].replace(class2label)
df_mt[TOPIC_COL] = "random"
df_mt[DATASET_COL] = "MT"
df_mt[DOMAIN_COL] = "random"
df_mt[DSID_COL] = df_mt[DATASET_COL] + "_" + df_mt[DSID_COL]
df_mt = df_mt.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_mt = df_mt[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]

show_information(df_mt)
df_mt.to_csv(path + final, index=False)
# Out:
# MT size: 449
# Topics: 1

# %%
# !find ./data/MT -mindepth 1 -not -name 'mt.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create WD

# %%
! git clone https://github.com/UKPLab/emnlp2017-claim-identification.git
! mkdir ./data/WD
! unzip ./emnlp2017-claim-identification/src/main/python/data.zip -d ./data/WD/data
! rm -r ./emnlp2017-claim-identification
# Out:
# Cloning into 'emnlp2017-claim-identification'...
# remote: Enumerating objects: 328, done.
# remote: Total 328 (delta 0), reused 0 (delta 0), pack-reused 328 (from 1)
# Receiving objects: 100% (328/328), 12.56 MiB | 8.57 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# Updating files: 100% (138/138), done.
# mkdir: cannot create directory ‘./data/WD’: File exists
# Archive:  ./emnlp2017-claim-identification/src/main/python/data.zip
#    creating: ./data/WD/data/PE/
#   inflating: ./data/WD/data/PE/002.test
#   inflating: ./data/WD/data/PE/008.dev
#   inflating: ./data/WD/data/PE/009.train
#   inflating: ./data/WD/data/PE/009.dev
#   inflating: ./data/WD/data/PE/010.train
#   inflating: ./data/WD/data/WD/006.train
#   inflating: ./data/WD/data/WD/007.test
#   inflating: ./data/WD/data/WD/004.train
#   inflating: ./data/WD/data/WD/002.dev
#   inflating: ./data/WD/data/WD/003.dev
#   inflating: ./data/WD/data/WD/003.train
#   inflating: ./data/WD/data/WD/001.train
#   inflating: ./data/WD/data/WD/001.dev
#   inflating: ./data/WD/data/WD/004.dev
#   inflating: ./data/WD/data/WD/010.dev
#   inflating: ./data/WD/data/WD/005.train
#   inflating: ./data/WD/data/WD/005.dev
#   inflating: ./data/WD/data/WD/007.dev
#   inflating: ./data/WD/data/WD/001.test
#   inflating: ./data/WD/data/WD/007.train
#   inflating: ./data/WD/data/WD/006.dev
#    creating: ./data/WD/data/WTP/
#   inflating: ./data/WD/data/WTP/002.test
#   inflating: ./data/WD/data/WTP/008.dev
#   inflating: ./data/WD/data/WTP/009.train
#   inflating: ./data/WD/data/WTP/009.dev
#   inflating: ./data/WD/data/WTP/010.train
#   inflating: ./data/WD/data/WTP/003.test
#   inflating: ./data/WD/data/WTP/008.train
#   inflating: ./data/WD/data/WTP/008.test
#   inflating: ./data/WD/data/WTP/004.test
#   inflating: ./data/WD/data/WTP/005.test
#   inflating: ./data/WD/data/WTP/009.test
#   inflating: ./data/WD/data/WTP/006.test
#   inflating: ./data/WD/data/WTP/002.train
#   inflating: ./data/WD/data/WTP/010.test
#   inflating: ./data/WD/data/WTP/006.train
#   inflating: ./data/WD/data/WTP/007.test
#   inflating: ./data/WD/data/WTP/004.train
#   inflating: ./data/WD/data/WTP/002.dev
#   inflating: ./data/WD/data/WTP/003.dev
#   inflating: ./data/WD/data/WTP/003.train
#   inflating: ./data/WD/data/WTP/001.train
#   inflating: ./data/WD/data/WTP/001.dev
#   inflating: ./data/WD/data/WTP/004.dev
#   inflating: ./data/WD/data/WTP/010.dev
#   inflating: ./data/WD/data/WTP/005.train
#   inflating: ./data/WD/data/WTP/005.dev
#   inflating: ./data/WD/data/WTP/007.dev
#   inflating: ./data/WD/data/WTP/001.test
#   inflating: ./data/WD/data/WTP/007.train
#   inflating: ./data/WD/data/WTP/006.dev
#   inflating: ./data/WD/data/README.md
#   inflating: ./data/WD/data/__MACOSX/._README.md

# %%
path = "./data/WD/"
final = "wd.csv"

class2label = {1: ARGUMENT, 0: NOARGUMENT}
df_wd = pd.DataFrame()

for f in os.listdir(path + "data/WD"):
    if not (f.endswith(".train") or f.endswith(".dev") or f.endswith(".test")):
        continue
    data = []
    content = read_file(path + f"data/WD/{f}")
    for line in content.splitlines():
        sentence, label = line.split("\t")
        data.append((sentence.strip(), int(label)))

    df = pd.DataFrame(data, columns=[SENTENCE_COL, LABEL_COL])
    df[DSID_COL] = df.apply(lambda row: f.replace('.', '_') + "_" + str(row.name), axis=1)
    df_wd = pd.concat([df_wd, df])

df_wd[LABEL_COL] = df_wd[LABEL_COL].replace(class2label)
df_wd[TOPIC_COL] = "random"
df_wd[DATASET_COL] = "WD"
df_wd[DOMAIN_COL] = "random"
df_wd[DSID_COL] = df_wd[DATASET_COL] + "_" + df_wd[DSID_COL]
df_wd = df_wd.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_wd = df_wd[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]

show_information(df_wd)
df_wd.to_csv(path + final, index=False)
# Out:
# WD size: 3872
# Topics: 1

# %%
# !find ./data/WD -mindepth 1 -not -name 'wd.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create VG

# %%
! git clone https://github.com/UKPLab/emnlp2017-claim-identification.git
! mkdir ./data/VG
! unzip ./emnlp2017-claim-identification/src/main/python/data.zip -d ./data/VG/data
! rm -r ./emnlp2017-claim-identification
# Out:
# Cloning into 'emnlp2017-claim-identification'...
# remote: Enumerating objects: 328, done.
# remote: Total 328 (delta 0), reused 0 (delta 0), pack-reused 328 (from 1)
# Receiving objects: 100% (328/328), 12.56 MiB | 14.80 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# Updating files: 100% (138/138), done.
# mkdir: cannot create directory ‘./data/VG’: File exists
# Archive:  ./emnlp2017-claim-identification/src/main/python/data.zip
#    creating: ./data/VG/data/PE/
#   inflating: ./data/VG/data/PE/002.test
#   inflating: ./data/VG/data/PE/008.dev
#   inflating: ./data/VG/data/PE/009.train
#   inflating: ./data/VG/data/PE/009.dev
#   inflating: ./data/VG/data/PE/010.train
#   inflating: ./data/VG/data/PE/003.test
#   inflating: ./data/VG/data/PE/008.train
#   inflating: ./data/VG/data/PE/008.test
#   inflating: ./data/VG/data/PE/004.test
#   inflating: ./data/VG/data/PE/005.test
#   inflating: ./data/VG/data/PE/009.test
#   inflating: ./data/VG/data/PE/006.test
#   inflating: ./data/VG/data/PE/002.train
#   inflating: ./data/VG/data/PE/010.test
#   inflating: ./data/VG/data/PE/006.train
#   inflating: ./data/VG/data/PE/007.test
#   inflating: ./data/VG/data/PE/004.train
#   inflating: ./data/VG/data/PE/002.dev
#   inflating: ./data/VG/data/PE/003.dev
#   inflating: ./data/VG/data/PE/003.train
#   inflating: ./data/VG/data/PE/001.train
#   inflating: ./data/VG/data/PE/001.dev
#   inflating: ./data/VG/data/PE/004.dev
#   inflating: ./data/VG/data/PE/010.dev
#   inflating: ./data/VG/data/PE/005.train
#   inflating: ./data/VG/data/PE/005.dev
#   inflating: ./data/VG/data/PE/007.dev
#   inflating: ./data/VG/data/PE/001.test
#   inflating: ./data/VG/data/PE/007.train
#   inflating: ./data/VG/data/PE/006.dev
#    creating: ./data/VG/data/VG/
#   inflating: ./data/VG/data/VG/002.test
#   inflating: ./data/VG/data/VG/008.dev
#   inflating: ./data/VG/data/VG/009.train
#   inflating: ./data/VG/data/VG/009.dev
#   inflating: ./data/VG/data/VG/010.train
#   inflating: ./data/VG/data/VG/003.test
#   inflating: ./data/VG/data/VG/008.train
#   inflating: ./data/VG/data/VG/008.test
#   inflating: ./data/VG/data/VG/004.test
#   inflating: ./data/VG/data/VG/005.test
#   inflating: ./data/VG/data/VG/009.test
#   inflating: ./data/VG/data/VG/006.test
#   inflating: ./data/VG/data/VG/002.train
#   inflating: ./data/VG/data/VG/010.test
#   inflating: ./data/VG/data/VG/006.train
#   inflating: ./data/VG/data/VG/007.test
#   inflating: ./data/VG/data/VG/004.train
#   inflating: ./data/VG/data/WTP/005.dev
#   inflating: ./data/VG/data/WTP/007.dev
#   inflating: ./data/VG/data/WTP/001.test
#   inflating: ./data/VG/data/WTP/007.train
#   inflating: ./data/VG/data/WTP/006.dev
#   inflating: ./data/VG/data/README.md
#   inflating: ./data/VG/data/__MACOSX/._README.md

# %%
path = "./data/VG/"
final = "vg.csv"

class2label = {1: ARGUMENT, 0: NOARGUMENT}
df_vg = pd.DataFrame()

for f in os.listdir(path + "data/VG"):
    if not (f.endswith(".train") or f.endswith(".dev") or f.endswith(".test")):
        continue
    data = []
    content = read_file(path + f"data/VG/{f}")
    for line in content.splitlines():
        sentence, label = line.split("\t")
        data.append((sentence.strip(), int(label)))

    df = pd.DataFrame(data, columns=[SENTENCE_COL, LABEL_COL])
    df[DSID_COL] = df.apply(lambda row: f.replace('.', '_') + "_" + str(row.name), axis=1)
    df_vg = pd.concat([df_vg, df])

df_vg[LABEL_COL] = df_vg[LABEL_COL].replace(class2label)
df_vg[TOPIC_COL] = "random"
df_vg[DATASET_COL] = "VG"
df_vg[DOMAIN_COL] = "www.aifdb.org"
df_vg[DSID_COL] = df_vg[DATASET_COL] + "_" + df_vg[DSID_COL]
df_vg = df_vg.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_vg = df_vg[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]

show_information(df_vg)
df_vg.to_csv(path + final, index=False)
# Out:
# VG size: 2576
# Topics: 1

# %%
# !find ./data/VG -mindepth 1 -not -name 'vg.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create TACO

# %%
! wget https://zenodo.org/records/8230057/files/TomatenMarc/TACO-Public-Data.zip
! mkdir -p ./data/TACO
! unzip -o TACO-Public-Data.zip -d ./data/TACO
! mv -f ./data/TACO/TomatenMarc-TACO-aa2c0cc/* ./data/TACO
! rm -r TACO-Public-Data.zip
! rm -r ./data/TACO/TomatenMarc-TACO-aa2c0cc/
# Out:
# --2024-12-29 14:40:10--  https://zenodo.org/records/8230057/files/TomatenMarc/TACO-Public-Data.zip
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7453512 (7.1M) [application/octet-stream]
# Saving to: ‘TACO-Public-Data.zip’
#
# TACO-Public-Data.zi 100%[===================>]   7.11M  7.27MB/s    in 1.0s
#
# 2024-12-29 14:40:12 (7.27 MB/s) - ‘TACO-Public-Data.zip’ saved [7453512/7453512]
#
# Archive:  TACO-Public-Data.zip
# aa2c0cc58a10a9833c2b8ded865205cd7d359156
#    creating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/.gitignore
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/README.md
#    creating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/data/
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/data/README.md
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/data/annotation_framework.pdf
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/data/conversations.csv
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/data/majority_votes.csv
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/data/worker_decisions.csv
#    creating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/notebooks/
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/notebooks/classifier_cv.ipynb
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/notebooks/dataset_statistics.ipynb
#    creating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/outputs/
#   inflating: ./data/TACO/TomatenMarc-TACO-aa2c0cc/outputs/bertweet_cv_predictions.csv

# %%
path = './data/TACO/'
final = 'taco.csv'
class2label = {"Reason": ARGUMENT, "Statement": ARGUMENT, "Notification": NOARGUMENT, "None": NOARGUMENT}

df_majority_votes = pd.read_csv(path + 'data/majority_votes.csv')
df_backup = pd.read_csv('./assets/backup_tweets.csv', lineterminator='\n')

df_taco = df_majority_votes.merge(df_backup, on='tweet_id')
df_taco['class'] = df_taco['class'].astype(str)
df_taco['class'] = df_taco['class'].replace({'nan': 'None'})
df_taco = df_taco[df_taco['class'] != "Undecided"]
df_taco['class'] = df_taco['class'].replace(class2label)

df_taco[DOMAIN_COL] = 'https://twitter.com'
df_taco = df_taco[['tweet_id', 'domain', 'topic', 'class', 'text']]
df_taco[DATASET_COL] = 'TACO'

df_taco.rename(columns={
    "tweet_id": DSID_COL,
    "topic": TOPIC_COL,
    "class": LABEL_COL,
    "text": SENTENCE_COL
}, inplace=True)

df_taco = df_taco[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_taco = df_taco.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_taco)
df_taco.to_csv(path + final, index=False)
# Out:
# TACO size: 1732
# Topics: 6

# %%
# !find ./data/TACO -mindepth 1 -not -name 'taco.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create AEC

# %%
! wget http://nldslab.soe.ucsc.edu/arg-extraction/sigdial2015/annotated-phrases-by-topic.tar.xz
! mkdir -p ./data/AEC
! tar -xf annotated-phrases-by-topic.tar.xz -C ./data/AEC
! rm -r annotated-phrases-by-topic.tar.xz
# Out:
# --2024-12-29 14:33:48--  http://nldslab.soe.ucsc.edu/arg-extraction/sigdial2015/annotated-phrases-by-topic.tar.xz
# Resolving nldslab.soe.ucsc.edu (nldslab.soe.ucsc.edu)... 128.114.48.41
# Connecting to nldslab.soe.ucsc.edu (nldslab.soe.ucsc.edu)|128.114.48.41|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 353008 (345K) [application/x-xz]
# Saving to: ‘annotated-phrases-by-topic.tar.xz’
#
# annotated-phrases-b 100%[===================>] 344.73K  1011KB/s    in 0.3s
#
# 2024-12-29 14:33:48 (1011 KB/s) - ‘annotated-phrases-by-topic.tar.xz’ saved [353008/353008]

# %%
path = './data/AEC/'
final = 'aec.csv'

topic_mapping = {
    'gm': "gay marriage",
    'evo': "evoluation",
    'gc': "gun control",
    'dp': "death penalty"
}

class2label = {'no_connective': NOARGUMENT, 'so': ARGUMENT, 'if': ARGUMENT, 'but': ARGUMENT, 'first': ARGUMENT, "i agree that": ARGUMENT}

dataframes = []
for file in os.listdir(path):
    file_path = os.path.join(path, file)
    if file != final:
        dataframe = pd.read_csv(file_path)
        topic_prefix = file.split('-')[0]
        topic = topic_mapping.get(topic_prefix, None)
        dataframe['topic'] = topic
        dataframe[DOMAIN_COL] = "http://www.createdebate.com/"
        dataframes.append(dataframe)

df_aec = pd.concat(dataframes)

df_aec['Connective.x'] = df_aec['Connective.x'].replace(class2label)

df_aec = df_aec[['ItemId', DOMAIN_COL, 'topic', 'Connective.x', 'Phrase.x']]
df_aec[DATASET_COL] = 'AEC'
df_aec.rename(columns={
    "ItemId": DSID_COL,
    "topic": TOPIC_COL,
    "Connective.x": LABEL_COL,
    "Phrase.x": SENTENCE_COL
}, inplace=True)

df_aec = df_aec[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_aec.sort_values(by=DSID_COL)
df_aec = df_aec.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_aec)
df_aec.to_csv(path + final, index=False)
# Out:
# AEC size: 5375
# Topics: 4

# %%
# !find ./data/AEC -mindepth 1 -not -name 'aec.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create UKP

# %%
! mkdir -p ./data/UKP
! unzip -o ./assets/UKP_sentential_argument_mining.zip -d ./data/UKP
# Out:
# Archive:  ./assets/UKP_sentential_argument_mining.zip
#    creating: ./data/UKP/data/
#   inflating: ./data/UKP/data/abortion.tsv
#   inflating: ./data/UKP/data/cloning.tsv
#   inflating: ./data/UKP/data/death_penalty.tsv
#   inflating: ./data/UKP/data/gun_control.tsv
#   inflating: ./data/UKP/data/marijuana_legalization.tsv
#   inflating: ./data/UKP/data/minimum_wage.tsv
#   inflating: ./data/UKP/data/nuclear_energy.tsv
#   inflating: ./data/UKP/data/school_uniforms.tsv
#   inflating: ./data/UKP/README.txt

# %%
path = './data/UKP/'
final = 'ukp.csv'

ARGUMENT_FOR = 'Argument_for'
ARGUMENT_AGAINST = 'Argument_against'
NO_ARGUMENT = 'NoArgument'

class2label = {ARGUMENT_FOR: ARGUMENT, ARGUMENT_AGAINST: ARGUMENT, NO_ARGUMENT: NOARGUMENT}
# school_uniforms.tsv contains an error in the last line.
dataframes = [pd.read_csv(os.path.join(path+"data/", file), delimiter='\\t', engine="python") for file in os.listdir(path+"data/") if file != final]

df_ukp = pd.concat(dataframes)
df_ukp['annotation'] = df_ukp['annotation'].replace(class2label)

df_ukp = df_ukp[['sentenceHash', 'retrievedUrl', 'topic', 'annotation', 'sentence']]
df_ukp[DATASET_COL] = "UKP"

df_ukp.rename(columns={
    "sentenceHash": DSID_COL,
    "retrievedUrl": DOMAIN_COL,
    "topic": TOPIC_COL,
    "annotation": LABEL_COL,
    "sentence": SENTENCE_COL
}, inplace=True)

df_ukp = df_ukp[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_ukp = df_ukp.loc[~df_ukp[DSID_COL].duplicated()]
df_ukp = df_ukp.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])
df_ukp.sort_values(by=DSID_COL)

show_information(df_ukp)
df_ukp.to_csv(path+final, index=False)
# Out:
# UKP size: 25104
# Topics: 8

# %%
# !find ./data/UKP -mindepth 1 -not -name 'ukp.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create ASRD

# %%
! wget https://www.research.ibm.com/haifa/dept/vst/files/IBM_Debater_\(R\)_ArgsInASR_Findings-2020.v1.zip
! mkdir -p ./data/ASRD
! unzip -o IBM_Debater_\(R\)_ArgsInASR_Findings-2020.v1.zip -d ./data/ASRD
! mv -f ./data/ASRD/IBM_Debater_\(R\)_ArgsInASR_Findings-2020.v1/* ./data/ASRD
! rm IBM_Debater_\(R\)_ArgsInASR_Findings-2020.v1.zip
! rm -r ./data/ASRD/__MACOSX
! rm -r ./data/ASRD/IBM_Debater_\(R\)_ArgsInASR_Findings-2020.v1
# Out:
# --2024-12-30 17:36:07--  https://www.research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1.zip
# Resolving www.research.ibm.com (www.research.ibm.com)... 13.32.230.22, 13.32.230.125, 13.32.230.11, ...
# Connecting to www.research.ibm.com (www.research.ibm.com)|13.32.230.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1.zip [following]
# --2024-12-30 17:36:07--  https://research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1.zip
# Resolving research.ibm.com (research.ibm.com)... 108.138.106.92, 108.138.106.96, 108.138.106.127, ...
# Connecting to research.ibm.com (research.ibm.com)|108.138.106.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 130274 (127K) [application/zip]
# Saving to: ‘IBM_Debater_(R)_ArgsInASR_Findings-2020.v1.zip’
#
# IBM_Debater_(R)_Arg 100%[===================>] 127.22K   540KB/s    in 0.2s
#
# 2024-12-30 17:36:08 (540 KB/s) - ‘IBM_Debater_(R)_ArgsInASR_Findings-2020.v1.zip’ saved [130274/130274]
#
# Archive:  IBM_Debater_(R)_ArgsInASR_Findings-2020.v1.zip
#    creating: ./data/ASRD/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1/
#   inflating: ./data/ASRD/__MACOSX/._IBM_Debater_(R)_ArgsInASR_Findings-2020.v1
#   inflating: ./data/ASRD/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1/argumentative_sentences_in_spoken_language_with split.csv
#   inflating: ./data/ASRD/__MACOSX/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1/._argumentative_sentences_in_spoken_language_with split.csv
#   inflating: ./data/ASRD/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1/README.txt
#   inflating: ./data/ASRD/__MACOSX/IBM_Debater_(R)_ArgsInASR_Findings-2020.v1/._README.txt

# %%
path = './data/ASRD/'
final = 'asrd.csv'

class2label = {0: NOARGUMENT, 1: ARGUMENT}

df_asrd = pd.read_csv(path+'argumentative_sentences_in_spoken_language_with split.csv')
df_asrd['label'] = df_asrd['label'].replace(class2label)
df_asrd['sentence_id'] = "ASRD-" + df_asrd['sentence_id'].astype(str)
df_asrd["sentence"] = df_asrd["sentence"] + "."
df_asrd[DOMAIN_COL] = "ASR Debate Speeches"
df_asrd[DATASET_COL] = "ASRD"
df_asrd.rename(columns={"sentence_id": DSID_COL}, inplace=True)
df_asrd = df_asrd[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_asrd = df_asrd.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_asrd)
df_asrd.to_csv(path+final, index=False)
# Out:
# ASRD size: 700
# Topics: 20

# %%
# !find ./data/ASRD -mindepth 1 -not -name 'asrd.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create QMC

# %%
! wget https://www.research.ibm.com/haifa/dept/vst/files/IBM_Debater_\(R\)_claim_sentences_search.zip
! mkdir -p ./data/QMC
! unzip -o IBM_Debater_\(R\)_claim_sentences_search.zip -d ./data/QMC
! rm -r IBM_Debater_\(R\)_claim_sentences_search.zip
# Out:
# --2024-12-29 14:10:09--  https://www.research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_claim_sentences_search.zip
# Resolving www.research.ibm.com (www.research.ibm.com)... 13.32.230.11, 13.32.230.125, 13.32.230.22, ...
# Connecting to www.research.ibm.com (www.research.ibm.com)|13.32.230.11|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_claim_sentences_search.zip [following]
# --2024-12-29 14:10:09--  https://research.ibm.com/haifa/dept/vst/files/IBM_Debater_(R)_claim_sentences_search.zip
# Resolving research.ibm.com (research.ibm.com)... 108.138.106.96, 108.138.106.92, 108.138.106.72, ...
# Connecting to research.ibm.com (research.ibm.com)|108.138.106.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 121145170 (116M) [application/zip]
# Saving to: ‘IBM_Debater_(R)_claim_sentences_search.zip’
#
# IBM_Debater_(R)_cla 100%[===================>] 115.53M  35.7MB/s    in 4.6s
#
# 2024-12-29 14:10:14 (25.0 MB/s) - ‘IBM_Debater_(R)_claim_sentences_search.zip’ saved [121145170/121145170]
#
# Archive:  IBM_Debater_(R)_claim_sentences_search.zip
#    creating: ./data/QMC/data_sets/
#   inflating: ./data/QMC/data_sets/q_mc_heldout.csv
#   inflating: ./data/QMC/data_sets/test_set.csv
#   inflating: ./data/QMC/data_sets/q_mc_test.csv
#   inflating: ./data/QMC/data_sets/readme_test_set.txt
#   inflating: ./data/QMC/data_sets/readme_mc_queries.txt
#   inflating: ./data/QMC/data_sets/q_mc_train.csv

# %%
path = './data/QMC/'
final = 'qmc.csv'

column_names = ['id', 'topic', 'mc', 'sentence', 'query_pattern', 'score', 'label', 'url']
df_qmc = pd.read_csv(path+'data_sets/test_set.csv', header=None, names=column_names)
df_qmc['label'] = df_qmc['label'].replace(class2label)
df_qmc['id'] = "QMC-" + df_qmc.index.astype(str)
df_qmc[DATASET_COL] = 'QMC'
df_qmc.rename(columns={"id": DSID_COL, "url": DOMAIN_COL}, inplace=True)
df_qmc = df_qmc[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_qmc = df_qmc.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_qmc)
df_qmc.to_csv(path+final, index=False)
# Out:
# QMC size: 2499
# Topics: 50

# %%
# !find ./data/QMC -mindepth 1 -not -name 'qmc.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create IAM

# %%
! wget https://github.com/LiyingCheng95/IAM/archive/refs/heads/main.zip
! mkdir -p ./data/IAM
! unzip -o main.zip -d ./data/IAM
! mv -f ./data/IAM/IAM-main/* ./data/IAM
! rm -r main.zip
! rm -r ./data/IAM/IAM-main/
# Out:
# --2024-12-29 14:49:17--  https://github.com/LiyingCheng95/IAM/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/LiyingCheng95/IAM/zip/refs/heads/main [following]
# --2024-12-29 14:49:18--  https://codeload.github.com/LiyingCheng95/IAM/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [        <=>         ]  14.55M  5.14MB/s    in 2.8s
#
# 2024-12-29 14:49:21 (5.14 MB/s) - ‘main.zip’ saved [15253078]
#
# Archive:  main.zip
# 5497013e36a6af07a798b42965e6a3c321aa56ae
#    creating: ./data/IAM/IAM-main/
#    creating: ./data/IAM/IAM-main/CEPE/
#   inflating: ./data/IAM/IAM-main/CEPE/dev.json
#   inflating: ./data/IAM/IAM-main/CEPE/dev.txt
#   inflating: ./data/IAM/IAM-main/CEPE/process_json.py
#   inflating: ./data/IAM/IAM-main/CEPE/test.json
#   inflating: ./data/IAM/IAM-main/CEPE/test.txt
#   inflating: ./data/IAM/IAM-main/CEPE/train.txt
#    creating: ./data/IAM/IAM-main/CESC/
#   inflating: ./data/IAM/IAM-main/CESC/main.py
#   inflating: ./data/IAM/IAM-main/CESC/train.py
#   inflating: ./data/IAM/IAM-main/README.md
#    creating: ./data/IAM/IAM-main/claims/
#   inflating: ./data/IAM/IAM-main/claims/all_claims.txt
#   inflating: ./data/IAM/IAM-main/claims/dev.txt
#   inflating: ./data/IAM/IAM-main/claims/main.py
#   inflating: ./data/IAM/IAM-main/claims/test.txt
#   inflating: ./data/IAM/IAM-main/claims/train.py
#   inflating: ./data/IAM/IAM-main/claims/train.txt
#    creating: ./data/IAM/IAM-main/evidence/
#   inflating: ./data/IAM/IAM-main/evidence/dev.txt
#   inflating: ./data/IAM/IAM-main/evidence/evidences1.txt
#   inflating: ./data/IAM/IAM-main/evidence/main.py
#   inflating: ./data/IAM/IAM-main/evidence/test.txt
#   inflating: ./data/IAM/IAM-main/evidence/train.py
#   inflating: ./data/IAM/IAM-main/evidence/train.txt
#    creating: ./data/IAM/IAM-main/stance/
#   inflating: ./data/IAM/IAM-main/stance/dev.txt
#   inflating: ./data/IAM/IAM-main/stance/main.py
#   inflating: ./data/IAM/IAM-main/stance/test.txt
#   inflating: ./data/IAM/IAM-main/stance/train.py
#   inflating: ./data/IAM/IAM-main/stance/train.txt
#    creating: ./data/IAM/IAM-main/stance_Chinese/
#   inflating: ./data/IAM/IAM-main/stance_Chinese/test.txt
#   inflating: ./data/IAM/IAM-main/stance_Chinese/train.txt

# %%
path = './data/IAM/'
final = 'iam.csv'
class2label = {"C": ARGUMENT, "O": NOARGUMENT}
column_names = ['claim_label', 'topic_sentence', 'claim_candidate_sentence', 'article_id', 'stance_label']
df_iam = pd.read_csv(path + 'claims/all_claims.txt', header=None, delimiter='\t', names=column_names)
df_iam['claim_label'] = df_iam['claim_label'].replace(class2label)
df_iam[DSID_COL] = "IAM-" + df_iam.index.astype(str)
df_iam[DATASET_COL] = 'IAM'
df_iam[DOMAIN_COL] = 'www.wikipedia.com/' + df_iam.article_id.astype(str)

df_iam.rename(columns={"topic_sentence": TOPIC_COL,
                       "claim_label": LABEL_COL,
                       "claim_candidate_sentence": SENTENCE_COL},
              inplace=True)
df_iam = df_iam[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_iam = df_iam.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_iam)
df_iam.to_csv(path+final, index=False)
# Out:
# IAM size: 66524
# Topics: 100

# %%
# !find ./data/IAM -mindepth 1 -not -name 'iam.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create AMSR

# %%
! wget https://zenodo.org/records/4314390/files/AMSR.zip
! mkdir -p ./data/AMSR
! unzip -o AMSR.zip data/conferences_annotated/sentence_level/* -d ./data/AMSR
! mv -f ./data/AMSR/data/conferences_annotated/sentence_level/* ./data/AMSR
! rm -r AMSR.zip
! rm -r ./data/AMSR/data
# Out:
# --2024-12-29 14:26:43--  https://zenodo.org/records/4314390/files/AMSR.zip
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58882809 (56M) [application/octet-stream]
# Saving to: ‘AMSR.zip’
#
# AMSR.zip            100%[===================>]  56.15M  16.7MB/s    in 3.4s
#
# 2024-12-29 14:26:47 (16.7 MB/s) - ‘AMSR.zip’ saved [58882809/58882809]
#
# Archive:  AMSR.zip
#    creating: ./data/AMSR/data/conferences_annotated/sentence_level/
#   inflating: ./data/AMSR/data/conferences_annotated/sentence_level/all_reviews_by_sentences.csv
#   inflating: ./data/AMSR/data/conferences_annotated/sentence_level/test.csv
#   inflating: ./data/AMSR/data/conferences_annotated/sentence_level/train.csv
#   inflating: ./data/AMSR/data/conferences_annotated/sentence_level/val.csv

# %%
path = './data/AMSR/'
final = 'amsr.csv'
class2label = {"POS": ARGUMENT, "NEG": ARGUMENT, "NA": NOARGUMENT}

df_amsr = [pd.read_csv(os.path.join(path, file), delimiter='\t', engine="python") for file in ["train.csv", "val.csv", "test.csv"]]
df_amsr = pd.concat(df_amsr)
df_amsr['position'] = df_amsr['position'].apply(lambda text: text.strip())
df_amsr['position'] = df_amsr['position'].replace(class2label)
df_amsr[DATASET_COL] = 'AMSR'
df_amsr[DOMAIN_COL] = 'www.openreview.com/' + df_amsr.sentence_id.astype(str)
df_amsr[TOPIC_COL] = df_amsr["sentence_id"].apply(lambda text: text.split('_')[0])
df_amsr.rename(columns={"sentence_id": DSID_COL,
                       "position": LABEL_COL,
                       "text": SENTENCE_COL},
              inplace=True)
df_amsr = df_amsr[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_amsr = df_amsr.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_amsr)
df_amsr.to_csv(path+final, index=False)
# Out:
# AMSR size: 1400
# Topics: 6

# %%
# !find ./data/AMSR -mindepth 1 -not -name 'amsr.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create AMPERE

# %%
! wget http://xinyuhua.github.io/resources/naacl2019/naacl19_dataset.zip
! unzip -o naacl19_dataset.zip -d ./data/AMPERE
! mv -f ./data/AMPERE/dataset ./data/AMPERE/data
! rm -r naacl19_dataset.zip
# Out:
# --2024-12-29 14:01:37--  http://xinyuhua.github.io/resources/naacl2019/naacl19_dataset.zip
# Resolving xinyuhua.github.io (xinyuhua.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to xinyuhua.github.io (xinyuhua.github.io)|185.199.108.153|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15682546 (15M) [application/zip]
# Saving to: ‘naacl19_dataset.zip’
#
# naacl19_dataset.zip 100%[===================>]  14.96M  46.4MB/s    in 0.3s
#
# 2024-12-29 14:01:38 (46.4 MB/s) - ‘naacl19_dataset.zip’ saved [15682546/15682546]
#
# Archive:  naacl19_dataset.zip
#    creating: ./data/AMPERE/dataset/
#   inflating: ./data/AMPERE/dataset/README
#   inflating: ./data/AMPERE/dataset/annotation_guideline.txt
#   inflating: ./data/AMPERE/dataset/iclr2017.jsonlist
#   inflating: ./data/AMPERE/dataset/iclr2018.jsonlist
#    creating: ./data/AMPERE/dataset/iclr_anno_final/
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B104VQCgM_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B10Nn-jlf_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B129GzFxf_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B143HDlWM_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1A7YkceM_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1B3e0Oef_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1BFRS7ZM_rating_2.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1FEuWcez_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1Fe0Zqxz_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1IwI-2xz_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1LfYs_gf_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1MeHT3rG_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1P-gBclf_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1RZJ1cxG_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1ZlEVXyf_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1_TQ-clG_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1chwjFlz_rating_8.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1eq0Hqlz_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1fZIQcxM_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1g5pBTxz_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1ja8-9lf_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1m1clFlM_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1oFM1FeG_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1pcOYBlG_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1qbgHcxz_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1qhp-qeG_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/B1y7_3YgM_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJ0qmr9xf_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJ1X3tYgf_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJ2J7pFgf_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJ3VB6_xG_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJ9DfkxWM_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJAg3e7ZM_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJBU32dgz_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJBWMqqlf_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJCXSFZgz_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJDxbMvez_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJFxOpcez_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJGc-k9xG_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJGq_QclM_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJHcawFxM_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJHwtGogM_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJJTve9gM_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJQD_I_eM_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJQGTw5lM_rating_2.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJSfkUNzf_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJTS11qlz_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJfU-qDeG_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJggQbceG_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJiW7IkZM_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJovaI9gf_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BJu6VdYlf_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk-6h6Txz_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk-lFRWWz_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk1-V2plG_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk15lpF1G_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk2K_F9lz_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk3B7T5gf_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk6nbuf-M_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk8FeZjgf_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk8udEEeM_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk9Z3ZQlG_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk9oIe5gG_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkC-HgcxG_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkC87_Cgz_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkCxP2Fez_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkE3cW5gG_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkEYMCPlG_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkEcWHKlf_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkH22ZFxG_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkL0g3a1f_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkMvqjYgG_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkOfh_eWM_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkQD60b-f_rating_4.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkSq8vBxG_rating_2.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkTXGMKlf_rating_3.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkTles9xM_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkWlPOFlM_rating_6.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkYfM_Rgz_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/BkYwge9ef_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/Bk_UdcKxf_rating_5.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/
txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/ryx2q7_eG_rating_7.txt
#   inflating: ./data/AMPERE/dataset/iclr_anno_final/tmp
#   inflating: ./data/AMPERE/dataset/test_ids.txt
#   inflating: ./data/AMPERE/dataset/train_ids.txt
#   inflating: ./data/AMPERE/dataset/uai2018.jsonlist

# %%
path = './data/AMPERE/'
final = 'ampere.csv'
class2label = {"fact": ARGUMENT, "evaluation": ARGUMENT, "request": ARGUMENT, "reference": ARGUMENT, "quote": ARGUMENT, "non-arg": NOARGUMENT}

df_ampere = pd.DataFrame()

for file_name in tqdm(os.listdir(path + "data/iclr_anno_final")):
    if file_name.endswith('tmp'):
        continue
    file_path = path + "data/iclr_anno_final/" + file_name
    # Parse labeled data and generate label positions
    labeled_data = parse_labeled_file(file_path)
    combined_text, label_positions = generate_label_positions(labeled_data)
    # Match annotations to sentences
    sentence_annotations = match_annotations_to_sentences(combined_text, label_positions)
    # Prepare output and create DataFrame
    output_data = prepare_output(sentence_annotations)
    df_output = pd.DataFrame(output_data)
    df_output[DSID_COL] = df_output.apply(lambda row: file_name.split(".txt")[0] + "_" + str(row.name), axis=1)
    df_ampere = pd.concat([df_ampere, df_output])

# Display or save the final DataFrame
df_ampere = df_ampere[df_ampere[LABEL_COL] != set()] # exclude those without labels.
df_ampere[LABEL_COL] = df_ampere[LABEL_COL].apply(lambda row: row != set(["non-arg"]))
df_ampere[LABEL_COL] = df_ampere[LABEL_COL].replace({True: ARGUMENT, False: NOARGUMENT})
df_ampere[DOMAIN_COL] = 'www.openreview.com/'
df_ampere[DATASET_COL] = 'AMPERE'
df_ampere[TOPIC_COL] = "random"
df_ampere = df_ampere[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_ampere = df_ampere.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_ampere)
df_ampere.to_csv(path+final, index=False)
# Out:
#   0%|          | 0/401 [00:00<?, ?it/s]
# AMPERE size: 6971
# Topics: 1

# %%
# !find ./data/AMPERE -mindepth 1 -not -name 'ampere.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create FINARG

# %%
# !git clone https://github.com/Alaa-Ah/The-FinArg-Dataset-Argument-Mining-in-Financial-Earnings-Calls
! unzip -o ./The-FinArg-Dataset-Argument-Mining-in-Financial-Earnings-Calls/FinArg.zip -d ./data/FINARG
! rm -r ./The-FinArg-Dataset-Argument-Mining-in-Financial-Earnings-Calls/
! mv ./data/FINARG/argument\ mining ./data/FINARG/data
# Out:
# Cloning into 'The-FinArg-Dataset-Argument-Mining-in-Financial-Earnings-Calls'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 45 (delta 23), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 5.23 MiB | 10.21 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Archive:  ./The-FinArg-Dataset-Argument-Mining-in-Financial-Earnings-Calls/FinArg.zip
#    creating: ./data/FINARG/argument mining/
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17544.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17544_9.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17545.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17545_9.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17546.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17546_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17547.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17547_9.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17548.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17548_9.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17549.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17549_9.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17551.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17551_9.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17552.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2015_17552_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17575.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17575_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17576.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17576_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17577.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17577_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17578.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17578_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17579.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17579_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17580.json
#  extracting: ./data/FINARG/argument mining/AAPL_Q1_2016_17580_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17581.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17581_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17582.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17582_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17583.json
#  extracting: ./data/FINARG/argument mining/AAPL_Q1_2016_17583_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17584.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17584_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17585.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2016_17585_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2017_20339.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2017_20339_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2017_20340.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2017_20340_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2017_20341.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2017_20341_5.ann
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_2017_20342.json
#   inflating: ./data/FINARG/argument mining/AAPL_Q1_
json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17178_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17179.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17179_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17180.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17180_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17181.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17181_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17182.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17182_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17183.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17183_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17184.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17184_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17185.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2016_17185_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17861.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17861_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17862.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17862_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17863.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17863_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17864.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17864_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17865.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17865_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17866.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17866_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17867.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17867_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17868.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17868_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17869.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17869_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17870.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2017_17870_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17903.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17903_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17904.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17904_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17905.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17905_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17906.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17906_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17907.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17907_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17908.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17908_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17909.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17909_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17911.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17911_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17912.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2018_17912_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17943.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17943_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17944.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17944_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17945.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17945_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17946.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17946_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17947.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17947_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17948.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17948_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17949.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17949_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17950.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17950_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17951.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q3_2019_17951_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17145.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17145_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17146.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17146_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17147.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17147_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17148.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17148_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17149.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17149_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17150.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17150_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17151.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17151_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17153.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17153_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17154.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2015_17154_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17186.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17186_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17187.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17187_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17188.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17188_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17189.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17189_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17190.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17190_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17191.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17191_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17192.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17192_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17193.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17193_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17194.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17194_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17195.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17195_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17196.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2016_17196_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17871.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17871_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17872.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17872_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17873.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17873_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17874.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17874_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17875.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17875_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17876.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17876_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17877.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17877_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17878.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17878_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17879.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17879_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17880.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17880_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17881.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2017_17881_6.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17913.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17913_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17914.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17914_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17915.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17915_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17916.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17916_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17917.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17917_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17918.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17918_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17919.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17919_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17920.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17920_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17921.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17921_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17922.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2018_17922_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17952.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17952_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17953.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17953_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17954.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17954_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17955.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17955_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17956.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17956_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17957.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17957_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17958.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17958_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17959.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17959_7.ann
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17960.json
#   inflating: ./data/FINARG/argument mining/MSFT_Q4_2019_17960_7.ann

# %%
path = './data/FINARG/'
final = 'finarg.csv'

df_finarg = pd.DataFrame()
for f in tqdm(os.listdir(path + "data")):
    topic = f.split('_')[0].replace('AAPL', 'Apple').replace('AMZN', 'Amazon').replace('FB', 'Facebook').replace('MSFT', 'Microsoft')
    if f.endswith(".ann"):
        df = read_and_merge_annotations(path + "data/" + f)
        df[TOPIC_COL] = topic
        df[DSID_COL] = df.apply(lambda row: f.split(".")[0] + "_" + str(row.name), axis=1)
        df_finarg = pd.concat([df_finarg, df])

df_finarg[DATASET_COL] = "FINARG"
df_finarg[DOMAIN_COL] = "https://site.financialmodelingprep.com"
df_finarg[LABEL_COL] = df_finarg[LABEL_COL].apply(lambda row: any("claim" in label.lower() for label in row))
df_finarg[LABEL_COL] = df_finarg[LABEL_COL].replace({True: ARGUMENT, False: NOARGUMENT})
df_finarg = df_finarg[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_finarg = df_finarg.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_finarg)
df_finarg.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/1672 [00:00<?, ?it/s]
# FINARG size: 12917
# Topics: 4

# %%
# !find ./data/FINARG -mindepth 1 -not -name 'finarg.csv' \( -type f -exec rm -f {} + -o -type d -exec rm -r {} + \)

# %% [markdown]
# ## Create ABSTRCT

# %%
! wget https://gitlab.com/tomaye/abstrct/-/archive/master/abstrct-master.zip
! mkdir -p ./data/ABSTRCT
! unzip -o abstrct-master.zip -d ./data/ABSTRCT
! rm -r abstrct-master.zip
# Out:
# --2024-12-29 14:16:06--  https://gitlab.com/tomaye/abstrct/-/archive/master/abstrct-master.zip
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: �
ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23139058.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23182307.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23182307.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23185753.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23185753.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23211715.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23211715.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23224689.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23224689.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23245940.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23245940.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23254324.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23254324.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23284036.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23284036.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23379385.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23379385.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23406994.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23406994.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23439759.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23439759.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23455717.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23455717.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23466360.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23466360.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23477998.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23477998.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23504821.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23504821.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23525453.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23525453.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23549581.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23549581.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23551928.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23551928.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23562564.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23562564.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23569311.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23569311.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23589316.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23589316.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23866850.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23866850.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23873790.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23873790.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23910712.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23910712.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23917308.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23917308.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23945243.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23945243.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23962028.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23962028.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23989945.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23989945.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23993401.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/23993401.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/24001635.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/24001635.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/24067488.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/24067488.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/24075621.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/24075621.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7502428.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7502428.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7680374.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7680374.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7786823.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7786823.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7989941.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/7989941.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/8229122.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/8229122.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/8628043.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/8628043.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9166485.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9166485.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9402173.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9402173.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9414057.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9414057.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9496390.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9496390.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9531327.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9531327.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9554521.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9554521.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9667255.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9667255.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9747868.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9747868.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9790546.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9790546.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9807987.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9807987.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9849452.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9849452.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9849454.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9849454.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9850014.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9850014.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9890172.ann
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data/train/neoplasm_train/9890172.txt
#   inflating: ./data/ABSTRCT/abstrct-master/AbstRCT_corpus/readme.txt
#   inflating: ./data/ABSTRCT/abstrct-master/LICENSE
#   inflating: ./data/ABSTRCT/abstrct-master/README.md
#   inflating: ./data/ABSTRCT/abstrct-master/get_stats.py

# %%
# %%bash
# #!/bin/bash
#
# # Define source and destination directories
# src_dir="./data/ABSTRCT/abstrct-master/AbstRCT_corpus/data"
# dest_dir="./data/ABSTRCT/data"
#
# # Create destination directory if it doesn't exist
# mkdir -p "$dest_dir"
#
# # Iterate over all .ann files in the source directory
# find "$src_dir" -type f -name "*.ann" | while read -r ann_file; do
#     # Derive corresponding .txt file
#     txt_file="${ann_file%.ann}.txt"
#
#     # Check if the .txt file exists
#     if [[ -f "$txt_file" ]]; then
#         # Extract parent directory name
#         parent_dir=$(basename "$(dirname "$ann_file")")
#
#         # Get base filenames
#         ann_filename=$(basename "$ann_file")
#         txt_filename=$(basename "$txt_file")
#
#         # Define new filenames with parent directory prefix
#         new_ann="${parent_dir}_${ann_filename}"
#         new_txt="${parent_dir}_${txt_filename}"
#
#         # Copy .ann file if not already present
#         if [[ ! -e "$dest_dir/$new_ann" ]]; then
#             cp "$ann_file" "$dest_dir/$new_ann"
#             echo "Copied: $new_ann"
#         else
#             echo "Skipped duplicate: $new_ann"
#         fi
#
#         # Copy .txt file if not already present
#         if [[ ! -e "$dest_dir/$new_txt" ]]; then
#             cp "$txt_file" "$dest_dir/$new_txt"
#             echo "Copied: $new_txt"
#         else
#             echo "Skipped duplicate: $new_txt"
#         fi
#     else
#         echo "Missing .txt for: $ann_file"
#     fi
# done
# Out:
# Copied: neoplasm_dev_10735891.ann
# Copied: neoplasm_dev_10735891.txt
# Copied: neoplasm_dev_10811675.ann
# Copied: neoplasm_dev_10811675.txt
# Copied: neoplasm_dev_11766999.ann
# Copied: neoplasm_dev_11766999.txt
# Copied: neoplasm_dev_11786563.ann
# Copied: neoplasm_dev_11786563.txt
# Copied: neoplasm_dev_11788911.ann
# Copied: neoplasm_dev_11788911.txt
# Copied: neoplasm_dev_11790211.ann
# Copied: neoplasm_dev_11790211.txt
# Copied: neoplasm_dev_11821453.ann
# Copied: neoplasm_dev_11821453.txt
# Copied: neoplasm_dev_11830607.ann
# Copied: neoplasm_dev_11830607.txt
# Copied: neoplasm_dev_11843249.ann
# Copied: neoplasm_dev_11843249.txt
# Copied: neoplasm_dev_11896110.ann
# Copied: neoplasm_dev_11896110.txt
# Copied: neoplasm_dev_16476840.ann
# Copied: neoplasm_dev_16476840.txt
# Copied: neoplasm_dev_16476841.ann
# Copied: neoplasm_dev_16476841.txt
# Copied: neoplasm_dev_16483488.ann
# Copied: neoplasm_dev_16483488.txt
# Copied: neoplasm_dev_16487438.ann
# Copied: neoplasm_dev_16487438.txt
# Copied: neoplasm_dev_17664467.ann
# Copied: neoplasm_dev_17664467.txt
# Copied: neoplasm_dev_19704057.ann
# Copied: neoplasm_dev_19704057.txt
# Copied: neoplasm_dev_20006921.ann
# Copied: neoplasm_dev_20006921.txt
# Copied: neoplasm_dev_20009826.ann
# Copied: neoplasm_dev_20009826.txt
# Copied: neoplasm_dev_20026818.ann
# Copied: neoplasm_dev_20026818.txt
# Copied: neoplasm_dev_20227168.ann
# Copied: neoplasm_dev_20227168.txt
# Copied: neoplasm_dev_20339140.ann
# Copied: neoplasm_dev_20339140.txt
# Copied: neoplasm_dev_20351334.ann
# Copied: neoplasm_dev_20351334.txt
# Copied: neoplasm_dev_20362386.ann
# Copied: neoplasm_dev_20362386.txt
# Copied: neoplasm_dev_21296449.ann
# Copied: neoplasm_dev_21296449.txt
# Copied: neoplasm_dev_21366974.ann
# Copied: neoplasm_dev_21366974.txt
# Copied: neoplasm_dev_22011650.ann
# Copied: neoplasm_dev_22011650.txt
# Copied: neoplasm_dev_22097195.ann
# Copied: neoplasm_dev_22097195.txt
# Copied: neoplasm_dev_22842422.ann
# Copied: neoplasm_dev_22842422.txt
# Copied: neoplasm_dev_22857983.ann
# Copied: neoplasm_dev_22857983.txt
# Copied: neoplasm_dev_22868247.ann
# Copied: neoplasm_dev_22868247.txt
# Copied: neoplasm_dev_22877848.ann
# Copied: neoplasm_dev_22877848.txt
# Copied: neoplasm_dev_22945882.ann
# Copied: neoplasm_dev_22945882.txt
# Copied: neoplasm_dev_23017512.ann
# Copied: neoplasm_dev_23017512.txt
# Copied: neoplasm_dev_23294853.ann
# Copied: neoplasm_dev_23294853.txt
# Copied: neoplasm_dev_23333117.ann
# Copied: neoplasm_dev_23333117.txt
# Copied: neoplasm_dev_23352440.ann
# Copied: neoplasm_dev_23352440.txt
# Copied: neoplasm_dev_23404211.ann
# Copied: neoplasm_dev_23404211.txt
# Copied: neoplasm_dev_23545101.ann
# Copied: neoplasm_dev_23545101.txt
# Copied: neoplasm_dev_23657969.ann
# Copied: neoplasm_dev_23657969.txt
# Copied: neoplasm_dev_23686277.ann
# Copied: neoplasm_dev_23686277.txt
# Copied: neoplasm_dev_23690410.ann
# Copied: neoplasm_dev_23690410.txt
# Copied: neoplasm_dev_23696477.ann
# Copied: neoplasm_dev_23696477.txt
# Copied: neoplasm_dev_24045440.ann
# Copied: neoplasm_dev_24045440.txt
# Copied: neoplasm_dev_24084921.ann
# Copied: neoplasm_dev_24084921.txt
# Copied: neoplasm_dev_24092240.ann
# Copied: neoplasm_dev_24092240.txt
# Copied: neoplasm_dev_24123482.ann
# Copied: neoplasm_dev_24123482.txt
# Copied: neoplasm_dev_9093725.ann
# Copied: neoplasm_dev_9093725.txt
# Copied: neoplasm_dev_9106647.ann
# Copied: neoplasm_dev_9106647.txt
# Copied: neoplasm_dev_9137798.ann
# Copied: neoplasm_dev_9137798.txt
# Copied: neoplasm_dev_9143576.ann
# Copied: neoplasm_dev_9143576.txt
# Copied: glaucoma_test_10080213.ann
# Copied: glaucoma_test_10080213.txt
# Copied: glaucoma_test_10599663.ann
# Copied: glaucoma_test_10599663.txt
# Copied: glaucoma_test_10682964.ann
# Copied: glaucoma_test_10682964.txt
# Copied: glaucoma_test_10837379.ann
# Copied: glaucoma_test_10837379.txt
# Copied: glaucoma_test_10877373.ann
# Copied: glaucoma_test_10877373.txt
# Copied: glaucoma_test_10901475.ann
# Copied: glaucoma_test_10901475.txt
# Copied: glaucoma_test_11020403.ann
# Copied: glaucoma_test_11020403.txt
# Copied: glaucoma_test_11124286.ann
# Copied: glaucoma_test_11124286.txt
# Copied: glaucoma_test_11148810.ann
# Copied: glaucoma_test_11148810.txt
# Copied: glaucoma_test_11158795.ann
# Copied: glaucoma_test_11158795.txt
# Copied: glaucoma_test_11158796.ann
# Copied: glaucoma_test_11158796.txt
# Copied: glaucoma_test_11167277.ann
# Copied: glaucoma_test_11167277.txt
# Copied: glaucoma_test_11336940.ann
# Copied: glaucoma_test_11336940.txt
# Copied: glaucoma_test_11558817.ann
# Copied: glaucoma_test_11558817.txt
# Copied: glaucoma_test_11730649.ann
# Copied: glaucoma_test_11730649.txt
# Copied: glaucoma_test_11813932.ann
# Copied: glaucoma_test_11813932.txt
# Copied: glaucoma_test_11912355.ann
# Copied: glaucoma_test_11912355.txt
# Copied: glaucoma_test_12169965.ann
# Copied: glaucoma_test_12169965.txt
# Copied: glaucoma_test_12383808.ann
# Copied: glaucoma_test_12383808.txt
# Copied: glaucoma_test_12470755.ann
# Copied: glaucoma_test_12470755.txt
# Copied: glaucoma_test_12644943.ann
# Copied: glaucoma_test_12644943.txt
# Copied: glaucoma_test_12660585.ann
# Copied: glaucoma_test_12660585.txt
# Copied: glaucoma_test_12750084.ann
# Copied: glaucoma_test_12750084.txt
# Copied: glaucoma_test_12908569.ann
# Copied: glaucoma_test_12908569.txt
# Copied: glaucoma_test_14644719.ann
# Copied: glaucoma_test_14644719.txt
# Copied: glaucoma_test_14704542.ann
# Copied: glaucoma_test_14704542.txt
# Copied: glaucoma_test_14982045.ann
# Copied: glaucoma_test_14982045.txt
# Copied: glaucoma_test_15037889.ann
# Copied: glaucoma_test_15037889.txt
# Copied: glaucoma_test_15177955.ann
# Copied: glaucoma_test_15177955.txt
# Copied: glaucoma_test_15220019.ann
# Copied: glaucoma_test_15220019.txt
# Copied: glaucoma_test_15234141.ann
# Copied: glaucoma_test_15234141.txt
# Copied: glaucoma_test_15474813.ann
# Copied: glaucoma_test_15474813.txt
# Copied: glaucoma_test_15598478.ann
# Copied: glaucoma_test_15598478.txt
# Copied: glaucoma_test_1565457.ann
# Copied: glaucoma_test_1565457.txt
# Copied: glaucoma_test_15741820.ann
# Copied: glaucoma_test_15741820.txt
# Copied: glaucoma_test_16899528.ann
# Copied: glaucoma_test_16899528.txt
# Copied: glaucoma_test_17083910.ann
# Copied: glaucoma_test_17083910.txt
# Copied: glaucoma_test_17244215.ann
# Copied: glaucoma_test_17244215.txt
# Copied: glaucoma_test_17293790.ann
# Copied: glaucoma_test_17293790.txt
# Copied: glaucoma_test_17397924.ann
# Copied: glaucoma_test_17397924.txt
# Copied: glaucoma_test_17601060.ann
# Copied: glaucoma_test_17601060.txt
# Copied: glaucoma_test_17825417.ann
# Copied: glaucoma_test_17825417.txt
# Copied: glaucoma_test_17947826.ann
# Copied: glaucoma_test_17947826.txt
# Copied: glaucoma_test_18164068.ann
# Copied: glaucoma_test_18164068.txt
# Copied: glaucoma_test_18327364.ann
# Copied: glaucoma_test_18327364.txt
# Copied: glaucoma_test_18402717.ann
# Copied: glaucoma_test_18402717.txt
# Copied: glaucoma_test_1841578.ann
# Copied: glaucoma_test_1841578.txt
# Copied: glaucoma_test_18603947.ann
# Copied: glaucoma_test_18603947.txt
# Copied: glaucoma_test_18826749.ann
# Copied: glaucoma_test_18826749.txt
# Copied: glaucoma_test_19092465.ann
# Copied: glaucoma_test_19092465.txt
# Copied: glaucoma_test_19123151.ann
# Copied: glaucoma_test_19123151.txt
# Copied: glaucoma_test_19243831.ann
# Copied: glaucoma_test_19243831.txt
# Copied: glaucoma_test_19336424.ann
# Copied: glaucoma_test_19336424.txt
# Copied: glaucoma_test_19337705.ann
# Copied: glaucoma_test_19337705.txt
# Copied: glaucoma_test_19383599.ann
# Copied: glaucoma_test_19383599.txt
# Copied: glaucoma_test_19427617.ann
# Copied: glaucoma_test_19427617.txt
# Copied: glaucoma_test_19476406.ann
# Copied: glaucoma_test_19476406.txt
# Copied: glaucoma_test_19590523.ann
# Copied: glaucoma_test_19590523.txt
# Copied: glaucoma_test_19860553.ann
# Copied: glaucoma_test_19860553.txt
# Copied: glaucoma_test_19900212.ann
# Copied: glaucoma_test_19900212.txt
# Copied: glaucoma_test_20092592.ann
# Copied: glaucoma_test_20092592.txt
# Copied: glaucoma_test_20142538.ann
# Copied: glaucoma_test_20142538.txt
# Copied: glaucoma_test_20202537.ann
# Copied: glaucoma_test_20202537.txt
# Copied: glaucoma_test_20420586.ann
# Copied: glaucoma_test_20420586.txt
# Copied: glaucoma_test_20472226.ann
# Copied: glaucoma_test_20472226.txt
# Copied: glaucoma_test_20545217.ann
# Copied: glaucoma_test_20545217.txt
# Copied: glaucoma_test_20584708.ann
# Copied: glaucoma_test_20584708.txt
# Copied: glaucoma_test_20733558.ann
# Copied: glaucoma_test_20733558.txt
# Copied: glaucoma_test_20828829.ann
# Copied: glaucoma_test_20828829.txt
# Copied: glaucoma_test_21034177.ann
# Copied: glaucoma_test_21034177.txt
# Copied: glaucoma_test_21035866.ann
# Copied: glaucoma_test_21035866.txt
# Copied: glaucoma_test_21141017.ann
# Copied: glaucoma_test_21141017.txt
# Copied: glaucoma_test_21183518.ann
# Copied: glaucoma_test_21183518.txt
# Copied: glaucoma_test_21257146.ann
# Copied: glaucoma_test_21257146.txt
# Copied: glaucoma_test_21423036.ann
# Copied: glaucoma_test_21423036.txt
# Copied: glaucoma_test_21491994.ann
# Copied: glaucoma_test_21491994.txt
# Copied: glaucoma_test_21543992.ann
# Copied: glaucoma_test_21543992.txt
# Copied: glaucoma_test_21573097.ann
# Copied: glaucoma_test_21573097.txt
# Copied: glaucoma_test_21631670.ann
# Copied: glaucoma_test_21631670.txt
# Copied: glaucoma_test_21680022.ann
# Copied: glaucoma_test_21680022.txt
# Copied: glaucoma_test_21701528.ann
# Copied: glaucoma_test_21701528.txt
# Copied: glaucoma_test_21792284.ann
# Copied: glaucoma_test_21792284.txt
# Copied: glaucoma_test_21921953.ann
# Copied: glaucoma_test_21921953.txt
# Copied: glaucoma_test_22310086.ann
# Copied: glaucoma_test_22310086.txt
# Copied: glaucoma_test_22344189.ann
# Copied: glaucoma_test_22344189.txt
# Copied: glaucoma_test_22458918.ann
# Copied: glaucoma_test_22458918.txt
# Copied: glaucoma_test_22775229.ann
# Copied: glaucoma_test_22775229.txt
# Copied: glaucoma_test_22814041.ann
# Copied: glaucoma_test_22814041.txt
# Copied: glaucoma_test_22835512.ann
# Copied: glaucoma_test_22835512.txt
# Copied: glaucoma_test_22986111.ann
# Copied: glaucoma_test_22986111.txt
# Copied: glaucoma_test_23059481.ann
# Copied: glaucoma_test_23059481.txt
# Copied: glaucoma_test_23203707.ann
# Copied: glaucoma_test_23203707.txt
# Copied: glaucoma_test_23285843.ann
# Copied: glaucoma_test_23285843.txt
# Copied: glaucoma_test_23429621.ann
# Copied: glaucoma_test_23429621.txt
# Copied: glaucoma_test_28178150.ann
# Copied: glaucoma_test_28178150.txt
# Copied: glaucoma_test_8058290.ann
# Copied: glaucoma_test_8058290.txt
# Copied: glaucoma_test_8628543.ann
# Copied: glaucoma_test_8628543.txt
# Copied: glaucoma_test_8628544.ann
# Copied: glaucoma_test_8628544.txt
# Copied: glaucoma_test_9034838.ann
# Copied: glaucoma_test_9034838.txt
# Copied: glaucoma_test_9230823.ann
# Copied: glaucoma_test_9230823.txt
# Copied: mixed_test_10506606.ann
# Copied: mixed_test_10506606.txt
# Copied: mixed_test_10526263.ann
# Copied: mixed_test_10526263.txt
# Copied: mixed_test_11346336.ann
# Copied: mixed_test_11346336.txt
# Copied: mixed_test_11370551.ann
# Copied: mixed_test_11370551.txt
# Copied: mixed_test_11387359.ann
# Copied: mixed_test_11387359.txt
# Copied: mixed_test_11438417.ann
# Copied: mixed_test_11438417.txt
# Copied: mixed_test_11970761.ann
# Copied: mixed_test_11970761.txt
# Copied: mixed_test_12004217.ann
# Copied: mixed_test_12004217.txt
# Copied: mixed_test_12011126.ann
# Copied: mixed_test_12011126.txt
# Copied: mixed_test_12047964.ann
# Copied: mixed_test_12047964.txt
# Copied: mixed_test_12118024.ann
# Copied: mixed_test_12118024.txt
# Copied: mixed_test_12118027.ann
# Copied: mixed_test_12118027.txt
# Copied: mixed_test_12657097.ann
# Copied: mixed_test_12657097.txt
# Copied: mixed_test_12711121.ann
# Copied: mixed_test_12711121.txt
# Copied: mixed_test_12721238.ann
# Copied: mixed_test_12721238.txt
# Copied: mixed_test_12721239.ann
# Copied: mixed_test_12721239.txt
# Copied: mixed_test_12748244.ann
# Copied: mixed_test_12748244.txt
# Copied: mixed_test_12783373.ann
# Copied: mixed_test_12783373.txt
# Copied: mixed_test_12837811.ann
# Copied: mixed_test_12837811.txt
# Copied: mixed_test_12915593.ann
# Copied: mixed_test_12915593.txt
# Copied: mixed_test_22344189.ann
# Copied: mixed_test_22344189.txt
# Copied: mixed_test_22458918.ann
# Copied: mixed_test_22458918.txt
# Copied: mixed_test_22775229.ann
# Copied: mixed_test_22775229.txt
# Copied: mixed_test_22814041.ann
# Copied: mixed_test_22814041.txt
# Copied: mixed_test_22835512.ann
# Copied: mixed_test_22835512.txt
# Copied: mixed_test_22986111.ann
# Copied: mixed_test_22986111.txt
# Copied: mixed_test_23059481.ann
# Copied: mixed_test_23059481.txt
# Copied: mixed_test_23203707.ann
# Copied: mixed_test_23203707.txt
# Copied: mixed_test_23285843.ann
# Copied: mixed_test_23285843.txt
# Copied: mixed_test_23429621.ann
# Copied: mixed_test_23429621.txt
# Copied: mixed_test_27545497.ann
# Copied: mixed_test_27545497.txt
# Copied: mixed_test_27603149.ann
# Copied: mixed_test_27603149.txt
# Copied: mixed_test_27629859.ann
# Copied: mixed_test_27629859.txt
# Copied: mixed_test_28178150.ann
# Copied: mixed_test_28178150.txt
# Copied: mixed_test_28266150.ann
# Copied: mixed_test_28266150.txt
# Copied: mixed_test_28291960.ann
# Copied: mixed_test_28291960.txt
# Copied: mixed_test_28370419.ann
# Copied: mixed_test_28370419.txt
# Copied: mixed_test_28371482.ann
# Copied: mixed_test_28371482.txt
# Copied: mixed_test_28454526.ann
# Copied: mixed_test_28454526.txt
# Copied: mixed_test_28603112.ann
# Copied: mixed_test_28603112.txt
# Copied: mixed_test_28624326.ann
# Copied: mixed_test_28624326.txt
# Copied: mixed_test_28777224.ann
# Copied: mixed_test_28777224.txt
# Copied: mixed_test_28874133.ann
# Copied: mixed_test_28874133.txt
# Copied: mixed_test_28889724.ann
# Copied: mixed_test_28889724.txt
# Copied: mixed_test_28898281.ann
# Copied: mixed_test_28898281.txt
# Copied: mixed_test_28911991.ann
# Copied: mixed_test_28911991.txt
# Copied: mixed_test_28912358.ann
# Copied: mixed_test_28912358.txt
# Copied: mixed_test_28928855.ann
# Copied: mixed_test_28928855.txt
# Copied: mixed_test_29056008.ann
# Copied: mixed_test_29056008.txt
# Copied: mixed_test_29104121.ann
# Copied: mixed_test_29104121.txt
# Copied: mixed_test_29116050.ann
# Copied: mixed_test_29116050.txt
# Copied: mixed_test_29133641.ann
# Copied: mixed_test_29133641.txt
# Copied: mixed_test_29141712.ann
# Copied: mixed_test_29141712.txt
# Copied: mixed_test_29316213.ann
# Copied: mixed_test_29316213.txt
# Copied: mixed_test_29329305.ann
# Copied: mixed_test_29329305.txt
# Copied: mixed_test_29332633.ann
# Copied: mixed_test_29332633.txt
# Copied: mixed_test_29364091.ann
# Copied: mixed_test_29364091.txt
# Copied: mixed_test_29375225.ann
# Copied: mixed_test_29375225.txt
# Copied: mixed_test_29378197.ann
# Copied: mixed_test_29378197.txt
# Copied: mixed_test_29406428.ann
# Copied: mixed_test_29406428.txt
# Copied: mixed_test_29428751.ann
# Copied: mixed_test_29428751.txt
# Copied: mixed_test_29428785.ann
# Copied: mixed_test_29428785.txt
# Copied: mixed_test_29432772.ann
# Copied: mixed_test_29432772.txt
# Copied: mixed_test_29436152.ann
# Copied: mixed_test_29436152.txt
# Copied: mixed_test_29452204.ann
# Copied: mixed_test_29452204.txt
# Copied: mixed_test_29456079.ann
# Copied: mixed_test_29456079.txt
# Copied: mixed_test_29463627.ann
# Copied: mixed_test_29463627.txt
# Copied: mixed_test_29477688.ann
# Copied: mixed_test_29477688.txt
# Copied: mixed_test_29478187.ann
# Copied: mixed_test_29478187.txt
# Copied: mixed_test_29498351.ann
# Copied: mixed_test_29498351.txt
# Copied: mixed_test_29506674.ann
# Copied: mixed_test_29506674.txt
# Copied: mixed_test_29507099.ann
# Copied: mixed_test_29507099.txt
# Copied: mixed_test_29507944.ann
# Copied: mixed_test_29507944.txt
# Copied: mixed_test_29510792.ann
# Copied: mixed_test_29510792.txt
# Copied: mixed_test_29514030.ann
# Copied: mixed_test_29514030.txt
# Copied: mixed_test_29527973.ann
# Copied: mixed_test_29527973.txt
# Copied: mixed_test_29553852.ann
# Copied: mixed_test_29553852.txt
# Copied: mixed_test_29559030.ann
# Copied: mixed_test_29559030.txt
# Copied: mixed_test_29565948.ann
# Copied: mixed_test_29565948.txt
# Copied: mixed_test_29571976.ann
# Copied: mixed_test_29571976.txt
# Copied: mixed_test_29577107.ann
# Copied: mixed_test_29577107.txt
# Copied: mixed_test_29577550.ann
# Copied: mixed_test_29577550.txt
# Copied: mixed_test_29580746.ann
# Copied: mixed_test_29580746.txt
# Copied: mixed_test_29588137.ann
# Copied: mixed_test_29588137.txt
# Copied: mixed_test_29588138.ann
# Copied: mixed_test_29588138.txt
# Copied: mixed_test_29596950.ann
# Copied: mixed_test_29596950.txt
# Copied: mixed_test_29601076.ann
# Copied: mixed_test_29601076.txt
# Copied: mixed_test_29605574.ann
# Copied: mixed_test_29605574.txt
# Copied: mixed_test_29608107.ann
# Copied: mixed_test_29608107.txt
# Copied: mixed_test_29610590.ann
# Copied: mixed_test_29610590.txt
# Copied: mixed_test_29611209.ann
# Copied: mixed_test_29611209.txt
# Copied: mixed_test_29620663.ann
# Copied: mixed_test_29620663.txt
# Copied: mixed_test_29625440.ann
# Copied: mixed_test_29625440.txt
# Copied: mixed_test_29633159.ann
# Copied: mixed_test_29633159.txt
# Copied: mixed_test_29643323.ann
# Copied: mixed_test_29643323.txt
# Copied: mixed_test_29652567.ann
# Copied: mixed_test_29652567.txt
# Copied: mixed_test_29654381.ann
# Copied: mixed_test_29654381.txt
# Copied: mixed_test_29654388.ann
# Copied: mixed_test_29654388.txt
# Copied: mixed_test_29654849.ann
# Copied: mixed_test_29654849.txt
# Copied: mixed_test_29658370.ann
# Copied: mixed_test_29658370.txt
# Copied: neoplasm_test_10210927.ann
# Copied: neoplasm_test_10210927.txt
# Copied: neoplasm_test_10403690.ann
# Copied: neoplasm_test_10403690.txt
# Copied: neoplasm_test_10506606.ann
# Copied: neoplasm_test_10506606.txt
# Copied: neoplasm_test_10526263.ann
# Copied: neoplasm_test_10526263.txt
# Copied: neoplasm_test_11346336.ann
# Copied: neoplasm_test_11346336.txt
# Copied: neoplasm_test_11370551.ann
# Copied: neoplasm_test_11370551.txt
# Copied: neoplasm_test_11387359.ann
# Copied: neoplasm_test_11387359.txt
# Copied: neoplasm_test_11438417.ann
# Copied: neoplasm_test_11438417.txt
# Copied: neoplasm_test_11970761.ann
# Copied: neoplasm_test_11970761.txt
# Copied: neoplasm_test_12004217.ann
# Copied: neoplasm_test_12004217.txt
# Copied: neoplasm_test_12011126.ann
# Copied: neoplasm_test_12011126.txt
# Copied: neoplasm_test_12047964.ann
# Copied: neoplasm_test_12047964.txt
# Copied: neoplasm_test_12118024.ann
# Copied: neoplasm_test_12118024.txt
# Copied: neoplasm_test_12118027.ann
# Copied: neoplasm_test_12118027.txt
# Copied: neoplasm_test_12657097.ann
# Copied: neoplasm_test_12657097.txt
# Copied: neoplasm_test_12711121.ann
# Copied: neoplasm_test_12711121.txt
# Copied: neoplasm_test_12721238.ann
# Copied: neoplasm_test_12721238.txt
# Copied: neoplasm_test_12721239.ann
# Copied: neoplasm_test_12721239.txt
# Copied: neoplasm_test_12748244.ann
# Copied: neoplasm_test_12748244.txt
# Copied: neoplasm_test_12783373.ann
# Copied: neoplasm_test_12783373.txt
# Copied: neoplasm_test_12837811.ann
# Copied: neoplasm_test_12837811.txt
# Copied: neoplasm_test_12915593.ann
# Copied: neoplasm_test_12915593.txt
# Copied: neoplasm_test_12925071.ann
# Copied: neoplasm_test_12925071.txt
# Copied: neoplasm_test_15139072.ann
# Copied: neoplasm_test_15139072.txt
# Copied: neoplasm_test_15157043.ann
# Copied: neoplasm_test_15157043.txt
# Copied: neoplasm_test_15226325.ann
# Copied: neoplasm_test_15226325.txt
# Copied: neoplasm_test_15226773.ann
# Copied: neoplasm_test_15226773.txt
# Copied: neoplasm_test_15251160.ann
# Copied: neoplasm_test_15251160.txt
# Copied: neoplasm_test_15274068.ann
# Copied: neoplasm_test_15274068.txt
# Copied: neoplasm_test_15284262.ann
# Copied: neoplasm_test_15284262.txt
# Copied: neoplasm_test_15288288.ann
# Copied: neoplasm_test_15288288.txt
# Copied: neoplasm_test_16446330.ann
# Copied: neoplasm_test_16446330.txt
# Copied: neoplasm_test_16446335.ann
# Copied: neoplasm_test_16446335.txt
# Copied: neoplasm_test_16462503.ann
# Copied: neoplasm_test_16462503.txt
# Copied: neoplasm_test_16490846.ann
# Copied: neoplasm_test_16490846.txt
# Copied: neoplasm_test_16505413.ann
# Copied: neoplasm_test_16505413.txt
# Copied: neoplasm_test_16524633.ann
# Copied: neoplasm_test_16524633.txt
# Copied: neoplasm_test_16571129.ann
# Copied: neoplasm_test_16571129.txt
# Copied: neoplasm_test_17674351.ann
# Copied: neoplasm_test_17674351.txt
# Copied: neoplasm_test_17690882.ann
# Copied: neoplasm_test_17690882.txt
# Copied: neoplasm_test_17717452.ann
# Copied: neoplasm_test_17717452.txt
# Copied: neoplasm_test_17848814.ann
# Copied: neoplasm_test_17848814.txt
# Copied: neoplasm_test_17852440.ann
# Copied: neoplasm_test_17852440.txt
# Copied: neoplasm_test_17876009.ann
# Copied: neoplasm_test_17876009.txt
# Copied: neoplasm_test_18448745.ann
# Copied: neoplasm_test_18448745.txt
# Copied: neoplasm_test_18457329.ann
# Copied: neoplasm_test_18457329.txt
# Copied: neoplasm_test_18485819.ann
# Copied: neoplasm_test_18485819.txt
# Copied: neoplasm_test_18520802.ann
# Copied: neoplasm_test_18520802.txt
# Copied: neoplasm_test_18589314.ann
# Copied: neoplasm_test_18589314.txt
# Copied: neoplasm_test_18591549.ann
# Copied: neoplasm_test_18591549.txt
# Copied: neoplasm_test_18591555.ann
# Copied: neoplasm_test_18591555.txt
# Copied: neoplasm_test_18669464.ann
# Copied: neoplasm_test_18669464.txt
# Copied: neoplasm_test_20585099.ann
# Copied: neoplasm_test_20585099.txt
# Copied: neoplasm_test_20600809.ann
# Copied: neoplasm_test_20600809.txt
# Copied: neoplasm_test_20625123.ann
# Copied: neoplasm_test_20625123.txt
# Copied: neoplasm_test_20631341.ann
# Copied: neoplasm_test_20631341.txt
# Copied: neoplasm_test_20651011.ann
# Copied: neoplasm_test_20651011.txt
# Copied: neoplasm_test_20679600.ann
# Copied: neoplasm_test_20679600.txt
# Copied: neoplasm_test_20680680.ann
# Copied: neoplasm_test_20680680.txt
# Copied: neoplasm_test_20697941.ann
# Copied: neoplasm_test_20697941.txt
# Copied: neoplasm_test_20733132.ann
# Copied: neoplasm_test_20733132.txt
# Copied: neoplasm_test_20734132.ann
# Copied: neoplasm_test_20734132.txt
# Copied: neoplasm_test_20809177.ann
# Copied: neoplasm_test_20809177.txt
# Copied: neoplasm_test_20821047.ann
# Copied: neoplasm_test_20821047.txt
# Copied: neoplasm_test_21892106.ann
# Copied: neoplasm_test_21892106.txt
# Copied: neoplasm_test_21901389.ann
# Copied: neoplasm_test_21901389.txt
# Copied: neoplasm_test_21905158.ann
# Copied: neoplasm_test_21905158.txt
# Copied: neoplasm_test_21911723.ann
# Copied: neoplasm_test_21911723.txt
# Copied: neoplasm_test_21993852.ann
# Copied: neoplasm_test_21993852.txt
# Copied: neoplasm_test_23598172.ann
# Copied: neoplasm_test_23598172.txt
# Copied: neoplasm_test_23609927.ann
# Copied: neoplasm_test_23609927.txt
# Copied: neoplasm_test_23615094.ann
# Copied: neoplasm_test_23615094.txt
# Copied: neoplasm_test_23632471.ann
# Copied: neoplasm_test_23632471.txt
# Copied: neoplasm_test_23735703.ann
# Copied: neoplasm_test_23735703.txt
# Copied: neoplasm_test_23749688.ann
# Copied: neoplasm_test_23749688.txt
# Copied: neoplasm_test_23768153.ann
# Copied: neoplasm_test_23768153.txt
# Copied: neoplasm_test_23771714.ann
# Copied: neoplasm_test_23771714.txt
# Copied: neoplasm_test_23788218.ann
# Copied: neoplasm_test_23788218.txt
# Copied: neoplasm_test_23793805.ann
# Copied: neoplasm_test_23793805.txt
# Copied: neoplasm_test_23803270.ann
# Copied: neoplasm_test_23803270.txt
# Copied: neoplasm_test_23814044.ann
# Copied: neoplasm_test_23814044.txt
# Copied: neoplasm_test_23816967.ann
# Copied: neoplasm_test_23816967.txt
# Copied: neoplasm_test_23820680.ann
# Copied: neoplasm_test_23820680.txt
# Copied: neoplasm_test_23840308.ann
# Copied: neoplasm_test_23840308.txt
# Copied: neoplasm_test_23860204.ann
# Copied: neoplasm_test_23860204.txt
# Copied: neoplasm_test_24007947.ann
# Copied: neoplasm_test_24007947.txt
# Copied: neoplasm_test_24019545.ann
# Copied: neoplasm_test_24019545.txt
# Copied: neoplasm_test_24028441.ann
# Copied: neoplasm_test_24028441.txt
# Copied: neoplasm_test_24038913.ann
# Copied: neoplasm_test_24038913.txt
# Copied: neoplasm_test_24040301.ann
# Copied: neoplasm_test_24040301.txt
# Copied: neoplasm_test_24127364.ann
# Copied: neoplasm_test_24127364.txt
# Copied: neoplasm_test_24151326.ann
# Copied: neoplasm_test_24151326.txt
# Copied: neoplasm_test_24178750.ann
# Copied: neoplasm_test_24178750.txt
# Copied: neoplasm_test_24246508.ann
# Copied: neoplasm_test_24246508.txt
# Copied: neoplasm_test_8648360.ann
# Copied: neoplasm_test_8648360.txt
# Copied: neoplasm_test_8683634.ann
# Copied: neoplasm_test_8683634.txt
# Copied: neoplasm_test_8839553.ann
# Copied: neoplasm_test_8839553.txt
# Copied: neoplasm_test_9626213.ann
# Copied: neoplasm_test_9626213.txt
# Copied: neoplasm_test_9640214.ann
# Copied: neoplasm_test_9640214.txt
# Copied: neoplasm_test_9643663.ann
# Copied: neoplasm_test_9643663.txt
# Copied: neoplasm_train_10561201.ann
# Copied: neoplasm_train_10561201.txt
# Copied: neoplasm_train_10561203.ann
# Copied: neoplasm_train_10561203.txt
# Copied: neoplasm_train_10653877.ann
# Copied: neoplasm_train_10653877.txt
# Copied: neoplasm_train_10675381.ann
# Copied: neoplasm_train_10675381.txt
# Copied: neoplasm_train_10735887.ann
# Copied: neoplasm_train_10735887.txt
# Copied: neoplasm_train_10856098.ann
# Copied: neoplasm_train_10856098.txt
# Copied: neoplasm_train_10880548.ann
# Copied: neoplasm_train_10880548.txt
# Copied: neoplasm_train_10880550.ann
# Copied: neoplasm_train_10880550.txt
# Copied: neoplasm_train_10930797.ann
# Copied: neoplasm_train_10930797.txt
# Copied: neoplasm_train_10944126.ann
# Copied: neoplasm_train_10944126.txt
# Copied: neoplasm_train_10944130.ann
# Copied: neoplasm_train_10944130.txt
# Copied: neoplasm_train_11034245.ann
# Copied: neoplasm_train_11034245.txt
# Copied: neoplasm_train_11106123.ann
# Copied: neoplasm_train_11106123.txt
# Copied: neoplasm_train_11142481.ann
# Copied: neoplasm_train_11142481.txt
# Copied: neoplasm_train_11181777.ann
# Copied: neoplasm_train_11181777.txt
# Copied: neoplasm_train_11250991.ann
# Copied: neoplasm_train_11250991.txt
# Copied: neoplasm_train_11304763.ann
# Copied: neoplasm_train_11304763.txt
# Copied: neoplasm_train_12122096.ann
# Copied: neoplasm_train_12122096.txt
# Copied: neoplasm_train_12131085.ann
# Copied: neoplasm_train_12131085.txt
# Copied: neoplasm_train_12181240.ann
# Copied: neoplasm_train_12181240.txt
# Copied: neoplasm_train_12195763.ann
# Copied: neoplasm_train_12195763.txt
# Copied: neoplasm_train_12202326.ann
# Copied: neoplasm_train_12202326.txt
# Copied: neoplasm_train_12243809.ann
# Copied: neoplasm_train_12243809.txt
# Copied: neoplasm_train_12351592.ann
# Copied: neoplasm_train_12351592.txt
# Copied: neoplasm_train_12359855.ann
# Copied: neoplasm_train_12359855.txt
# Copied: neoplasm_train_12395333.ann
# Copied: neoplasm_train_12395333.txt
# Copied: neoplasm_train_12431965.ann
# Copied: neoplasm_train_12431965.txt
# Copied: neoplasm_train_12431971.ann
# Copied: neoplasm_train_12431971.txt
# Copied: neoplasm_train_12453852.ann
# Copied: neoplasm_train_12453852.txt
# Copied: neoplasm_train_12467070.ann
# Copied: neoplasm_train_12467070.txt
# Copied: neoplasm_train_12488409.ann
# Copied: neoplasm_train_12488409.txt
# Copied: neoplasm_train_12525531.ann
# Copied: neoplasm_train_12525531.txt
# Copied: neoplasm_train_12560436.ann
# Copied: neoplasm_train_12560436.txt
# Copied: neoplasm_train_12569144.ann
# Copied: neoplasm_train_12569144.txt
# Copied: neoplasm_train_12610178.ann
# Copied: neoplasm_train_12610178.txt
# Copied: neoplasm_train_12610183.ann
# Copied: neoplasm_train_12610183.txt
# Copied: neoplasm_train_12610188.ann
# Copied: neoplasm_train_12610188.txt
# Copied: neoplasm_train_12618501.ann
# Copied: neoplasm_train_12618501.txt
# Copied: neoplasm_train_12637459.ann
# Copied: neoplasm_train_12637459.txt
# Copied: neoplasm_train_12953086.ann
# Copied: neoplasm_train_12953086.txt
# Copied: neoplasm_train_12963704.ann
# Copied: neoplasm_train_12963704.txt
# Copied: neoplasm_train_14550448.ann
# Copied: neoplasm_train_14550448.txt
# Copied: neoplasm_train_14594437.ann
# Copied: neoplasm_train_14594437.txt
# Copied: neoplasm_train_14698542.ann
# Copied: neoplasm_train_14698542.txt
# Copied: neoplasm_train_14722035.ann
# Copied: neoplasm_train_14722035.txt
# Copied: neoplasm_train_14990635.ann
# Copied: neoplasm_train_14990635.txt
# Copied: neoplasm_train_14996859.ann
# Copied: neoplasm_train_14996859.txt
# Copied: neoplasm_train_15120769.ann
# Copied: neoplasm_train_15120769.txt
# Copied: neoplasm_train_15297582.ann
# Copied: neoplasm_train_15297582.txt
# Copied: neoplasm_train_15338385.ann
# Copied: neoplasm_train_15338385.txt
# Copied: neoplasm_train_15378098.ann
# Copied: neoplasm_train_15378098.txt
# Copied: neoplasm_train_15452187.ann
# Copied: neoplasm_train_15452187.txt
# Copied: neoplasm_train_15452188.ann
# Copied: neoplasm_train_15452188.txt
# Copied: neoplasm_train_15454357.ann
# Copied: neoplasm_train_15454357.txt
# Copied: neoplasm_train_15472910.ann
# Copied: neoplasm_train_15472910.txt
# Copied: neoplasm_train_15514373.ann
# Copied: neoplasm_train_15514373.txt
# Copied: neoplasm_train_15542159.ann
# Copied: neoplasm_train_15542159.txt
# Copied: neoplasm_train_15547181.ann
# Copied: neoplasm_train_15547181.txt
# Copied: neoplasm_train_15625369.ann
# Copied: neoplasm_train_15625369.txt
# Copied: neoplasm_train_15659490.ann
# Copied: neoplasm_train_15659490.txt
# Copied: neoplasm_train_15668285.ann
# Copied: neoplasm_train_15668285.txt
# Copied: neoplasm_train_15684319.ann
# Copied: neoplasm_train_15684319.txt
# Copied: neoplasm_train_15705087.ann
# Copied: neoplasm_train_15705087.txt
# Copied: neoplasm_train_15713598.ann
# Copied: neoplasm_train_15713598.txt
# Copied: neoplasm_train_15714933.ann
# Copied: neoplasm_train_15714933.txt
# Copied: neoplasm_train_15738537.ann
# Copied: neoplasm_train_15738537.txt
# Copied: neoplasm_train_15748464.ann
# Copied: neoplasm_train_15748464.txt
# Copied: neoplasm_train_15750359.ann
# Copied: neoplasm_train_15750359.txt
# Copied: neoplasm_train_15750360.ann
# Copied: neoplasm_train_15750360.txt
# Copied: neoplasm_train_15753541.ann
# Copied: neoplasm_train_15753541.txt
# Copied: neoplasm_train_15800308.ann
# Copied: neoplasm_train_15800308.txt
# Copied: neoplasm_train_15839957.ann
# Copied: neoplasm_train_15839957.txt
# Copied: neoplasm_train_15880316.ann
# Copied: neoplasm_train_15880316.txt
# Copied: neoplasm_train_15888157.ann
# Copied: neoplasm_train_15888157.txt
# Copied: neoplasm_train_15892043.ann
# Copied: neoplasm_train_15892043.txt
# Copied: neoplasm_train_15920748.ann
# Copied: neoplasm_train_15920748.txt
# Copied: neoplasm_train_16020979.ann
# Copied: neoplasm_train_16020979.txt
# Copied: neoplasm_train_16125515.ann
# Copied: neoplasm_train_16125515.txt
# Copied: neoplasm_train_16135469.ann
# Copied: neoplasm_train_16135469.txt
# Copied: neoplasm_train_16135471.ann
# Copied: neoplasm_train_16135471.txt
# Copied: neoplasm_train_16157934.ann
# Copied: neoplasm_train_16157934.txt
# Copied: neoplasm_train_16163445.ann
# Copied: neoplasm_train_16163445.txt
# Copied: neoplasm_train_16166415.ann
# Copied: neoplasm_train_16166415.txt
# Copied: neoplasm_train_16179098.ann
# Copied: neoplasm_train_16179098.txt
# Copied: neoplasm_train_16203762.ann
# Copied: neoplasm_train_16203762.txt
# Copied: neoplasm_train_16260701.ann
# Copied: neoplasm_train_16260701.txt
# Copied: neoplasm_train_16280763.ann
# Copied: neoplasm_train_16280763.txt
# Copied: neoplasm_train_16294343.ann
# Copied: neoplasm_train_16294343.txt
# Copied: neoplasm_train_16319148.ann
# Copied: neoplasm_train_16319148.txt
# Copied: neoplasm_train_16321761.ann
# Copied: neoplasm_train_16321761.txt
# Copied: neoplasm_train_16344321.ann
# Copied: neoplasm_train_16344321.txt
# Copied: neoplasm_train_16376417.ann
# Copied: neoplasm_train_16376417.txt
# Copied: neoplasm_train_16384850.ann
# Copied: neoplasm_train_16384850.txt
# Copied: neoplasm_train_16416368.ann
# Copied: neoplasm_train_16416368.txt
# Copied: neoplasm_train_16446322.ann
# Copied: neoplasm_train_16446322.txt
# Copied: neoplasm_train_16572647.ann
# Copied: neoplasm_train_16572647.txt
# Copied: neoplasm_train_16598426.ann
# Copied: neoplasm_train_16598426.txt
# Copied: neoplasm_train_16670385.ann
# Copied: neoplasm_train_16670385.txt
# Copied: neoplasm_train_16787687.ann
# Copied: neoplasm_train_16787687.txt
# Copied: neoplasm_train_16802254.ann
# Copied: neoplasm_train_16802254.txt
# Copied: neoplasm_train_16816536.ann
# Copied: neoplasm_train_16816536.txt
# Copied: neoplasm_train_16823511.ann
# Copied: neoplasm_train_16823511.txt
# Copied: neoplasm_train_16835585.ann
# Copied: neoplasm_train_16835585.txt
# Copied: neoplasm_train_16849753.ann
# Copied: neoplasm_train_16849753.txt
# Copied: neoplasm_train_16877734.ann
# Copied: neoplasm_train_16877734.txt
# Copied: neoplasm_train_16882940.ann
# Copied: neoplasm_train_16882940.txt
# Copied: neoplasm_train_16921034.ann
# Copied: neoplasm_train_16921034.txt
# Copied: neoplasm_train_16921047.ann
# Copied: neoplasm_train_16921047.txt
# Copied: neoplasm_train_16934909.ann
# Copied: neoplasm_train_16934909.txt
# Copied: neoplasm_train_16942833.ann
# Copied: neoplasm_train_16942833.txt
# Copied: neoplasm_train_16944295.ann
# Copied: neoplasm_train_16944295.txt
# Copied: neoplasm_train_16953985.ann
# Copied: neoplasm_train_16953985.txt
# Copied: neoplasm_train_16965866.ann
# Copied: neoplasm_train_16965866.txt
# Copied: neoplasm_train_16966687.ann
# Copied: neoplasm_train_16966687.txt
# Copied: neoplasm_train_16981945.ann
# Copied: neoplasm_train_16981945.txt
# Copied: neoplasm_train_17029276.ann
# Copied: neoplasm_train_17029276.txt
# Copied: neoplasm_train_17039380.ann
# Copied: neoplasm_train_17039380.txt
# Copied: neoplasm_train_17047644.ann
# Copied: neoplasm_train_17047644.txt
# Copied: neoplasm_train_17075117.ann
# Copied: neoplasm_train_17075117.txt
# Copied: neoplasm_train_17090981.ann
# Copied: neoplasm_train_17090981.txt
# Copied: neoplasm_train_17143593.ann
# Copied: neoplasm_train_17143593.txt
# Copied: neoplasm_train_17145528.ann
# Copied: neoplasm_train_17145528.txt
# Copied: neoplasm_train_17159194.ann
# Copied: neoplasm_train_17159194.txt
# Copied: neoplasm_train_17187405.ann
# Copied: neoplasm_train_17187405.txt
# Copied: neoplasm_train_17195085.ann
# Copied: neoplasm_train_17195085.txt
# Copied: neoplasm_train_17251532.ann
# Copied: neoplasm_train_17251532.txt
# Copied: neoplasm_train_17307761.ann
# Copied: neoplasm_train_17307761.txt
# Copied: neoplasm_train_17312332.ann
# Copied: neoplasm_train_17312332.txt
# Copied: neoplasm_train_17324657.ann
# Copied: neoplasm_train_17324657.txt
# Copied: neoplasm_train_17369574.ann
# Copied: neoplasm_train_17369574.txt
# Copied: neoplasm_train_17467230.ann
# Copied: neoplasm_train_17467230.txt
# Copied: neoplasm_train_17522936.ann
# Copied: neoplasm_train_17522936.txt
# Copied: neoplasm_train_17548243.ann
# Copied: neoplasm_train_17548243.txt
# Copied: neoplasm_train_17550132.ann
# Copied: neoplasm_train_17550132.txt
# Copied: neoplasm_train_17602075.ann
# Copied: neoplasm_train_17602075.txt
# Copied: neoplasm_train_17626056.ann
# Copied: neoplasm_train_17626056.txt
# Copied: neoplasm_train_17661342.ann
# Copied: neoplasm_train_17661342.txt
# Copied: neoplasm_train_17664468.ann
# Copied: neoplasm_train_17664468.txt
# Copied: neoplasm_train_17664469.ann
# Copied: neoplasm_train_17664469.txt
# Copied: neoplasm_train_17669280.ann
# Copied: neoplasm_train_17669280.txt
# Copied: neoplasm_train_17878480.ann
# Copied: neoplasm_train_17878480.txt
# Copied: neoplasm_train_17889449.ann
# Copied: neoplasm_train_17889449.txt
# Copied: neoplasm_train_17912635.ann
# Copied: neoplasm_train_17912635.txt
# Copied: neoplasm_train_17921185.ann
# Copied: neoplasm_train_17921185.txt
# Copied: neoplasm_train_17932908.ann
# Copied: neoplasm_train_17932908.txt
# Copied: neoplasm_train_17947724.ann
# Copied: neoplasm_train_17947724.txt
# Copied: neoplasm_train_17999405.ann
# Copied: neoplasm_train_17999405.txt
# Copied: neoplasm_train_18025439.ann
# Copied: neoplasm_train_18025439.txt
# Copied: neoplasm_train_18064563.ann
# Copied: neoplasm_train_18064563.txt
# Copied: neoplasm_train_18065731.ann
# Copied: neoplasm_train_18065731.txt
# Copied: neoplasm_train_18086760.ann
# Copied: neoplasm_train_18086760.txt
# Copied: neoplasm_train_18093738.ann
# Copied: neoplasm_train_18093738.txt
# Copied: neoplasm_train_18165645.ann
# Copied: neoplasm_train_18165645.txt
# Copied: neoplasm_train_18182665.ann
# Copied: neoplasm_train_18182665.txt
# Copied: neoplasm_train_18187401.ann
# Copied: neoplasm_train_18187401.txt
# Copied: neoplasm_train_18194401.ann
# Copied: neoplasm_train_18194401.txt
# Copied: neoplasm_train_18216523.ann
# Copied: neoplasm_train_18216523.txt
# Copied: neoplasm_train_18257399.ann
# Copied: neoplasm_train_18257399.txt
# Copied: neoplasm_train_18281662.ann
# Copied: neoplasm_train_18281662.txt
# Copied: neoplasm_train_18285602.ann
# Copied: neoplasm_train_18285602.txt
# Copied: neoplasm_train_18293016.ann
# Copied: neoplasm_train_18293016.txt
# Copied: neoplasm_train_18306372.ann
# Copied: neoplasm_train_18306372.txt
# Copied: neoplasm_train_18308419.ann
# Copied: neoplasm_train_18308419.txt
# Copied: neoplasm_train_18353696.ann
# Copied: neoplasm_train_18353696.txt
# Copied: neoplasm_train_18386580.ann
# Copied: neoplasm_train_18386580.txt
# Copied: neoplasm_train_18386581.ann
# Copied: neoplasm_train_18386581.txt
# Copied: neoplasm_train_18707619.ann
# Copied: neoplasm_train_18707619.txt
# Copied: neoplasm_train_18786981.ann
# Copied: neoplasm_train_18786981.txt
# Copied: neoplasm_train_18802161.ann
# Copied: neoplasm_train_18802161.txt
# Copied: neoplasm_train_18803678.ann
# Copied: neoplasm_train_18803678.txt
# Copied: neoplasm_train_18809612.ann
# Copied: neoplasm_train_18809612.txt
# Copied: neoplasm_train_18809617.ann
# Copied: neoplasm_train_18809617.txt
# Copied: neoplasm_train_18959455.ann
# Copied: neoplasm_train_18959455.txt
# Copied: neoplasm_train_19039808.ann
# Copied: neoplasm_train_19039808.txt
# Copied: neoplasm_train_19050973.ann
# Copied: neoplasm_train_19050973.txt
# Copied: neoplasm_train_19064973.ann
# Copied: neoplasm_train_19064973.txt
# Copied: neoplasm_train_19074911.ann
# Copied: neoplasm_train_19074911.txt
# Copied: neoplasm_train_19194996.ann
# Copied: neoplasm_train_19194996.txt
# Copied: neoplasm_train_19199105.ann
# Copied: neoplasm_train_19199105.txt
# Copied: neoplasm_train_19273701.ann
# Copied: neoplasm_train_19273701.txt
# Copied: neoplasm_train_19286422.ann
# Copied: neoplasm_train_19286422.txt
# Copied: neoplasm_train_19289630.ann
# Copied: neoplasm_train_19289630.txt
# Copied: neoplasm_train_19330830.ann
# Copied: neoplasm_train_19330830.txt
# Copied: neoplasm_train_19333052.ann
# Copied: neoplasm_train_19333052.txt
# Copied: neoplasm_train_19347979.ann
# Copied: neoplasm_train_19347979.txt
# Copied: neoplasm_train_19349389.ann
# Copied: neoplasm_train_19349389.txt
# Copied: neoplasm_train_19436289.ann
# Copied: neoplasm_train_19436289.txt
# Copied: neoplasm_train_19495810.ann
# Copied: neoplasm_train_19495810.txt
# Copied: neoplasm_train_19516032.ann
# Copied: neoplasm_train_19516032.txt
# Copied: neoplasm_train_19546404.ann
# Copied: neoplasm_train_19546404.txt
# Copied: neoplasm_train_19608997.ann
# Copied: neoplasm_train_19608997.txt
# Copied: neoplasm_train_19621686.ann
# Copied: neoplasm_train_19621686.txt
# Copied: neoplasm_train_19646443.ann
# Copied: neoplasm_train_19646443.txt
# Copied: neoplasm_train_19652072.ann
# Copied: neoplasm_train_19652072.txt
# Copied: neoplasm_train_19687337.ann
# Copied: neoplasm_train_19687337.txt
# Copied: neoplasm_train_19690306.ann
# Copied: neoplasm_train_19690306.txt
# Copied: neoplasm_train_19691092.ann
# Copied: neoplasm_train_19691092.txt
# Copied: neoplasm_train_19714296.ann
# Copied: neoplasm_train_19714296.txt
# Copied: neoplasm_train_19720909.ann
# Copied: neoplasm_train_19720909.txt
# Copied: neoplasm_train_19760046.ann
# Copied: neoplasm_train_19760046.txt
# Copied: neoplasm_train_19826172.ann
# Copied: neoplasm_train_19826172.txt
# Copied: neoplasm_train_19838842.ann
# Copied: neoplasm_train_19838842.txt
# Copied: neoplasm_train_19858379.ann
# Copied: neoplasm_train_19858379.txt
# Copied: neoplasm_train_19884558.ann
# Copied: neoplasm_train_19884558.txt
# Copied: neoplasm_train_20003966.ann
# Copied: neoplasm_train_20003966.txt
# Copied: neoplasm_train_20033227.ann
# Copied: neoplasm_train_20033227.txt
# Copied: neoplasm_train_20038728.ann
# Copied: neoplasm_train_20038728.txt
# Copied: neoplasm_train_20151824.ann
# Copied: neoplasm_train_20151824.txt
# Copied: neoplasm_train_20178647.ann
# Copied: neoplasm_train_20178647.txt
# Copied: neoplasm_train_20189927.ann
# Copied: neoplasm_train_20189927.txt
# Copied: neoplasm_train_20479425.ann
# Copied: neoplasm_train_20479425.txt
# Copied: neoplasm_train_20530648.ann
# Copied: neoplasm_train_20530648.txt
# Copied: neoplasm_train_20538475.ann
# Copied: neoplasm_train_20538475.txt
# Copied: neoplasm_train_20564162.ann
# Copied: neoplasm_train_20564162.txt
# Copied: neoplasm_train_20832982.ann
# Copied: neoplasm_train_20832982.txt
# Copied: neoplasm_train_20842129.ann
# Copied: neoplasm_train_20842129.txt
# Copied: neoplasm_train_20855825.ann
# Copied: neoplasm_train_20855825.txt
# Copied: neoplasm_train_20855843.ann
# Copied: neoplasm_train_20855843.txt
# Copied: neoplasm_train_20863761.ann
# Copied: neoplasm_train_20863761.txt
# Copied: neoplasm_train_20881891.ann
# Copied: neoplasm_train_20881891.txt
# Copied: neoplasm_train_20885302.ann
# Copied: neoplasm_train_20885302.txt
# Copied: neoplasm_train_20888993.ann
# Copied: neoplasm_train_20888993.txt
# Copied: neoplasm_train_20973982.ann
# Copied: neoplasm_train_20973982.txt
# Copied: neoplasm_train_21147514.ann
# Copied: neoplasm_train_21147514.txt
# Copied: neoplasm_train_21149651.ann
# Copied: neoplasm_train_21149651.txt
# Copied: neoplasm_train_21149658.ann
# Copied: neoplasm_train_21149658.txt
# Copied: neoplasm_train_21208247.ann
# Copied: neoplasm_train_21208247.txt
# Copied: neoplasm_train_21224783.ann
# Copied: neoplasm_train_21224783.txt
# Copied: neoplasm_train_21233603.ann
# Copied: neoplasm_train_21233603.txt
# Copied: neoplasm_train_21236344.ann
# Copied: neoplasm_train_21236344.txt
# Copied: neoplasm_train_21237636.ann
# Copied: neoplasm_train_21237636.txt
# Copied: neoplasm_train_21300923.ann
# Copied: neoplasm_train_21300923.txt
# Copied: neoplasm_train_21300930.ann
# Copied: neoplasm_train_21300930.txt
# Copied: neoplasm_train_21396307.ann
# Copied: neoplasm_train_21396307.txt
# Copied: neoplasm_train_21439726.ann
# Copied: neoplasm_train_21439726.txt
# Copied: neoplasm_train_21444867.ann
# Copied: neoplasm_train_21444867.txt
# Copied: neoplasm_train_21452066.ann
# Copied: neoplasm_train_21452066.txt
# Copied: neoplasm_train_21471765.ann
# Copied: neoplasm_train_21471765.txt
# Copied: neoplasm_train_21472373.ann
# Copied: neoplasm_train_21472373.txt
# Copied: neoplasm_train_21538678.ann
# Copied: neoplasm_train_21538678.txt
# Copied: neoplasm_train_21538680.ann
# Copied: neoplasm_train_21538680.txt
# Copied: neoplasm_train_21561791.ann
# Copied: neoplasm_train_21561791.txt
# Copied: neoplasm_train_21592754.ann
# Copied: neoplasm_train_21592754.txt
# Copied: neoplasm_train_21690465.ann
# Copied: neoplasm_train_21690465.txt
# Copied: neoplasm_train_21709202.ann
# Copied: neoplasm_train_21709202.txt
# Copied: neoplasm_train_21723792.ann
# Copied: neoplasm_train_21723792.txt
# Copied: neoplasm_train_21741309.ann
# Copied: neoplasm_train_21741309.txt
# Copied: neoplasm_train_21751205.ann
# Copied: neoplasm_train_21751205.txt
# Copied: neoplasm_train_21751295.ann
# Copied: neoplasm_train_21751295.txt
# Copied: neoplasm_train_21821474.ann
# Copied: neoplasm_train_21821474.txt
# Copied: neoplasm_train_21831722.ann
# Copied: neoplasm_train_21831722.txt
# Copied: neoplasm_train_21839414.ann
# Copied: neoplasm_train_21839414.txt
# Copied: neoplasm_train_21871978.ann
# Copied: neoplasm_train_21871978.txt
# Copied: neoplasm_train_22104618.ann
# Copied: neoplasm_train_22104618.txt
# Copied: neoplasm_train_22113257.ann
# Copied: neoplasm_train_22113257.txt
# Copied: neoplasm_train_22120301.ann
# Copied: neoplasm_train_22120301.txt
# Copied: neoplasm_train_22133572.ann
# Copied: neoplasm_train_22133572.txt
# Copied: neoplasm_train_22157367.ann
# Copied: neoplasm_train_22157367.txt
# Copied: neoplasm_train_22172923.ann
# Copied: neoplasm_train_22172923.txt
# Copied: neoplasm_train_22198049.ann
# Copied: neoplasm_train_22198049.txt
# Copied: neoplasm_train_22228392.ann
# Copied: neoplasm_train_22228392.txt
# Copied: neoplasm_train_22234519.ann
# Copied: neoplasm_train_22234519.txt
# Copied: neoplasm_train_22282373.ann
# Copied: neoplasm_train_22282373.txt
# Copied: neoplasm_train_22290808.ann
# Copied: neoplasm_train_22290808.txt
# Copied: neoplasm_train_22290823.ann
# Copied: neoplasm_train_22290823.txt
# Copied: neoplasm_train_22321518.ann
# Copied: neoplasm_train_22321518.txt
# Copied: neoplasm_train_22336221.ann
# Copied: neoplasm_train_22336221.txt
# Copied: neoplasm_train_22340282.ann
# Copied: neoplasm_train_22340282.txt
# Copied: neoplasm_train_22340966.ann
# Copied: neoplasm_train_22340966.txt
# Copied: neoplasm_train_22357901.ann
# Copied: neoplasm_train_22357901.txt
# Copied: neoplasm_train_22370314.ann
# Copied: neoplasm_train_22370314.txt
# Copied: neoplasm_train_22370330.ann
# Copied: neoplasm_train_22370330.txt
# Copied: neoplasm_train_22412149.ann
# Copied: neoplasm_train_22412149.txt
# Copied: neoplasm_train_22430268.ann
# Copied: neoplasm_train_22430268.txt
# Copied: neoplasm_train_22438297.ann
# Copied: neoplasm_train_22438297.txt
# Copied: neoplasm_train_22469559.ann
# Copied: neoplasm_train_22469559.txt
# Copied: neoplasm_train_22494567.ann
# Copied: neoplasm_train_22494567.txt
# Copied: neoplasm_train_22500884.ann
# Copied: neoplasm_train_22500884.txt
# Copied: neoplasm_train_22508621.ann
# Copied: neoplasm_train_22508621.txt
# Copied: neoplasm_train_22523181.ann
# Copied: neoplasm_train_22523181.txt
# Copied: neoplasm_train_22526159.ann
# Copied: neoplasm_train_22526159.txt
# Copied: neoplasm_train_22544562.ann
# Copied: neoplasm_train_22544562.txt
# Copied: neoplasm_train_22551127.ann
# Copied: neoplasm_train_22551127.txt
# Copied: neoplasm_train_22551128.ann
# Copied: neoplasm_train_22551128.txt
# Copied: neoplasm_train_22552194.ann
# Copied: neoplasm_train_22552194.txt
# Copied: neoplasm_train_22689807.ann
# Copied: neoplasm_train_22689807.txt
# Copied: neoplasm_train_22698292.ann
# Copied: neoplasm_train_22698292.txt
# Copied: neoplasm_train_22705939.ann
# Copied: neoplasm_train_22705939.txt
# Copied: neoplasm_train_22715124.ann
# Copied: neoplasm_train_22715124.txt
# Copied: neoplasm_train_22825506.ann
# Copied: neoplasm_train_22825506.txt
# Copied: neoplasm_train_22825550.ann
# Copied: neoplasm_train_22825550.txt
# Copied: neoplasm_train_22984910.ann
# Copied: neoplasm_train_22984910.txt
# Copied: neoplasm_train_23041585.ann
# Copied: neoplasm_train_23041585.txt
# Copied: neoplasm_train_23045575.ann
# Copied: neoplasm_train_23045575.txt
# Copied: neoplasm_train_23070101.ann
# Copied: neoplasm_train_23070101.txt
# Copied: neoplasm_train_23075680.ann
# Copied: neoplasm_train_23075680.txt
# Copied: neoplasm_train_23084254.ann
# Copied: neoplasm_train_23084254.txt
# Copied: neoplasm_train_23109700.ann
# Copied: neoplasm_train_23109700.txt
# Copied: neoplasm_train_23139058.ann
# Copied: neoplasm_train_23139058.txt
# Copied: neoplasm_train_23182307.ann
# Copied: neoplasm_train_23182307.txt
# Copied: neoplasm_train_23185753.ann
# Copied: neoplasm_train_23185753.txt
# Copied: neoplasm_train_23211715.ann
# Copied: neoplasm_train_23211715.txt
# Copied: neoplasm_train_23224689.ann
# Copied: neoplasm_train_23224689.txt
# Copied: neoplasm_train_23245940.ann
# Copied: neoplasm_train_23245940.txt
# Copied: neoplasm_train_23254324.ann
# Copied: neoplasm_train_23254324.txt
# Copied: neoplasm_train_23284036.ann
# Copied: neoplasm_train_23284036.txt
# Copied: neoplasm_train_23379385.ann
# Copied: neoplasm_train_23379385.txt
# Copied: neoplasm_train_23406994.ann
# Copied: neoplasm_train_23406994.txt
# Copied: neoplasm_train_23439759.ann
# Copied: neoplasm_train_23439759.txt
# Copied: neoplasm_train_23455717.ann
# Copied: neoplasm_train_23455717.txt
# Copied: neoplasm_train_23466360.ann
# Copied: neoplasm_train_23466360.txt
# Copied: neoplasm_train_23477998.ann
# Copied: neoplasm_train_23477998.txt
# Copied: neoplasm_train_23504821.ann
# Copied: neoplasm_train_23504821.txt
# Copied: neoplasm_train_23525453.ann
# Copied: neoplasm_train_23525453.txt
# Copied: neoplasm_train_23549581.ann
# Copied: neoplasm_train_23549581.txt
# Copied: neoplasm_train_23551928.ann
# Copied: neoplasm_train_23551928.txt
# Copied: neoplasm_train_23562564.ann
# Copied: neoplasm_train_23562564.txt
# Copied: neoplasm_train_23569311.ann
# Copied: neoplasm_train_23569311.txt
# Copied: neoplasm_train_23589316.ann
# Copied: neoplasm_train_23589316.txt
# Copied: neoplasm_train_23866850.ann
# Copied: neoplasm_train_23866850.txt
# Copied: neoplasm_train_23873790.ann
# Copied: neoplasm_train_23873790.txt
# Copied: neoplasm_train_23910712.ann
# Copied: neoplasm_train_23910712.txt
# Copied: neoplasm_train_23917308.ann
# Copied: neoplasm_train_23917308.txt
# Copied: neoplasm_train_23945243.ann
# Copied: neoplasm_train_23945243.txt
# Copied: neoplasm_train_23962028.ann
# Copied: neoplasm_train_23962028.txt
# Copied: neoplasm_train_23989945.ann
# Copied: neoplasm_train_23989945.txt
# Copied: neoplasm_train_23993401.ann
# Copied: neoplasm_train_23993401.txt
# Copied: neoplasm_train_24001635.ann
# Copied: neoplasm_train_24001635.txt
# Copied: neoplasm_train_24067488.ann
# Copied: neoplasm_train_24067488.txt
# Copied: neoplasm_train_24075621.ann
# Copied: neoplasm_train_24075621.txt
# Copied: neoplasm_train_7502428.ann
# Copied: neoplasm_train_7502428.txt
# Copied: neoplasm_train_7680374.ann
# Copied: neoplasm_train_7680374.txt
# Copied: neoplasm_train_7786823.ann
# Copied: neoplasm_train_7786823.txt
# Copied: neoplasm_train_7989941.ann
# Copied: neoplasm_train_7989941.txt
# Copied: neoplasm_train_8229122.ann
# Copied: neoplasm_train_8229122.txt
# Copied: neoplasm_train_8628043.ann
# Copied: neoplasm_train_8628043.txt
# Copied: neoplasm_train_9166485.ann
# Copied: neoplasm_train_9166485.txt
# Copied: neoplasm_train_9402173.ann
# Copied: neoplasm_train_9402173.txt
# Copied: neoplasm_train_9414057.ann
# Copied: neoplasm_train_9414057.txt
# Copied: neoplasm_train_9496390.ann
# Copied: neoplasm_train_9496390.txt
# Copied: neoplasm_train_9531327.ann
# Copied: neoplasm_train_9531327.txt
# Copied: neoplasm_train_9554521.ann
# Copied: neoplasm_train_9554521.txt
# Copied: neoplasm_train_9667255.ann
# Copied: neoplasm_train_9667255.txt
# Copied: neoplasm_train_9747868.ann
# Copied: neoplasm_train_9747868.txt
# Copied: neoplasm_train_9790546.ann
# Copied: neoplasm_train_9790546.txt
# Copied: neoplasm_train_9807987.ann
# Copied: neoplasm_train_9807987.txt
# Copied: neoplasm_train_9849452.ann
# Copied: neoplasm_train_9849452.txt
# Copied: neoplasm_train_9849454.ann
# Copied: neoplasm_train_9849454.txt
# Copied: neoplasm_train_9850014.ann
# Copied: neoplasm_train_9850014.txt
# Copied: neoplasm_train_9890172.ann
# Copied: neoplasm_train_9890172.txt

# %%
path = './data/ABSTRCT/'
final = 'abstrct.csv'

df_abstrct = pd.DataFrame()

for f in tqdm(set([f.split(".")[0] for f in os.listdir(path + "data")])):
    # Load and process files
    txt_path = path + f"data/{f}.txt"
    ann_path = path + f"data/{f}.ann"
    topic = f.split("_")[0]
    text_content = read_file(txt_path)
    annotation_lines = read_file(ann_path).splitlines()
    # Parse annotations
    parsed_annotations = parse_annotations(annotation_lines)
    # Match annotations to sentences
    sentence_annotations = match_annotations_to_sentences(text_content, parsed_annotations)
    # Prepare data for display
    output_data = prepare_output(sentence_annotations)
    # Create a DataFrame
    output_df = pd.DataFrame(output_data)
    output_df[TOPIC_COL] = topic
    output_df[DSID_COL] = output_df.apply(lambda row: f + "_" + str(row.name), axis=1)

    df_abstrct = pd.concat([df_abstrct, output_df])

df_abstrct[LABEL_COL] = df_abstrct[LABEL_COL].apply(lambda row: any("claim" in label.lower() for label in row))
df_abstrct[LABEL_COL] = df_abstrct[LABEL_COL].replace({True: ARGUMENT, False: NOARGUMENT})

df_abstrct[DATASET_COL] = "ABSTRCT"
df_abstrct[DOMAIN_COL] = "https://www.nlm.nih.gov"
df_abstrct = df_abstrct[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_abstrct = df_abstrct[~df_abstrct[DSID_COL].duplicated()]
df_abstrct = df_abstrct.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_abstrct)
df_abstrct = df_abstrct.sort_values(by=DSID_COL)
df_abstrct.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/700 [00:00<?, ?it/s]
# ABSTRCT size: 8632
# Topics: 3

# %%
# !find ./data/ABSTRCT -mindepth 1 ! -path "./data/ABSTRCT/abstrct.csv" -exec rm -rf {} +

# %% [markdown]
# ## Create ACQUA

# %%
! wget https://zenodo.org/records/3237552/files/ACQuA\ -\ CompArg\ -\ release\ v1\ -\ dataset\ of\ comparative\ sentences\ -\ all-data.csv

! mkdir -p ./data/ACQUA
! mv -f ACQuA\ -\ CompArg\ -\ release\ v1\ -\ dataset\ of\ comparative\ sentences\ -\ all-data.csv ./data/ACQUA
# Out:
# --2024-12-29 13:53:02--  https://zenodo.org/records/3237552/files/ACQuA%20-%20CompArg%20-%20release%20v1%20-%20dataset%20of%20comparative%20sentences%20-%20all-data.csv
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.48.194, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3231554 (3.1M) [text/plain]
# Saving to: ‘ACQuA - CompArg - release v1 - dataset of comparative sentences - all-data.csv’
#
# ACQuA - CompArg - r 100%[===================>]   3.08M  3.85MB/s    in 0.8s
#
# 2024-12-29 13:53:03 (3.85 MB/s) - ‘ACQuA - CompArg - release v1 - dataset of comparative sentences - all-data.csv’ saved [3231554/3231554]

# %%
path = './data/ACQUA/'
final = 'acqua.csv'

df_acqua = pd.read_csv(path + "ACQuA - CompArg - release v1 - dataset of comparative sentences - all-data.csv")
class2label = {"WORSE": ARGUMENT, "BETTER": ARGUMENT, "NONE": NOARGUMENT}

df_acqua.rename(columns={"id": DSID_COL,
                         "domain": TOPIC_COL,
                         "most_frequent_label": LABEL_COL,
                         "sentence": SENTENCE_COL},
                inplace=True)

df_acqua[DATASET_COL] = "ACQUA"
df_acqua[DOMAIN_COL] = "https://commoncrawl.org"
df_acqua = df_acqua[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_acqua[LABEL_COL] = df_acqua[LABEL_COL].replace(class2label)
df_acqua[TOPIC_COL] = df_acqua[TOPIC_COL].replace({"jbt": "random"})
df_acqua = df_acqua[~df_acqua[DSID_COL].duplicated(keep=False)]
df_acqua = df_acqua.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_acqua)
df_acqua.to_csv(path + final, index=False)
# Out:
# ACQUA size: 7185
# Topics: 3

# %%
! rm data/ACQUA/ACQuA\ -\ CompArg\ -\ release\ v1\ -\ dataset\ of\ comparative\ sentences\ -\ all-data.csv

# %% [markdown]
# ## Create WEBIS

# %%
! wget https://zenodo.org/records/3251804/files/webis-debate-16.tar.gz
! mkdir -p ./data/WEBIS
! tar -xf webis-debate-16.tar.gz -C ./data/WEBIS
! rm -r webis-debate-16.tar.gz
# Out:
# --2024-12-29 14:24:58--  https://zenodo.org/records/3251804/files/webis-debate-16.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 928453 (907K) [application/octet-stream]
# Saving to: ‘webis-debate-16.tar.gz’
#
# webis-debate-16.tar 100%[===================>] 906.69K  1.59MB/s    in 0.6s
#
# 2024-12-29 14:24:59 (1.59 MB/s) - ‘webis-debate-16.tar.gz’ saved [928453/928453]

# %%
path = './data/WEBIS/'
final = 'webis.csv'
class2label = {"Argumentative": ARGUMENT, "Non-Argumentative": NOARGUMENT}

df_webis = pd.DataFrame()
for f in tqdm(os.listdir(path + 'webis-debate-16/')):
    pattern = r"([a-zA-Z]+)(\d+)"
    fit = re.search(pattern, f)
    topic = fit.group(1)
    file_id = int(fit.group(2))

    column_names = [LABEL_COL, SENTENCE_COL]
    df = pd.read_csv(path + f'webis-debate-16/{f}', header=None, delimiter='\\t', engine='python', names=column_names)
    df[DSID_COL] = str(topic) + "-" + str(file_id) + "-" + df.index.astype(str)
    df[TOPIC_COL] = topic
    df[DOMAIN_COL] = "https://idebate.net"
    df[DATASET_COL] = "WEBIS"
    df_webis = pd.concat([df_webis, df])

df_webis = df_webis[[DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL]]
df_webis[LABEL_COL] = df_webis[LABEL_COL].replace(class2label)
df_webis = df_webis.drop_duplicates(subset=[SENTENCE_COL, LABEL_COL])

show_information(df_webis)
df_webis.to_csv(path + final, index=False)
# Out:
#   0%|          | 0/445 [00:00<?, ?it/s]
# WEBIS size: 16347
# Topics: 14

# %%
! rm -r ./data/WEBIS/webis-debate-16/

# %% [markdown]
# ## Combined data

# %%
df_combined = pd.DataFrame()
for f in os.listdir("./data"):
    path = "./data/" + f
    if os.path.isdir(path):
        df = pd.read_csv(path + "/" + f.lower() + ".csv")
        df = df[~df[SENTENCE_COL].isna()]
        assert not df[[SENTENCE_COL, LABEL_COL]].duplicated().any()
        assert all(df.columns == [DATASET_COL, DSID_COL, DOMAIN_COL, TOPIC_COL, LABEL_COL, SENTENCE_COL])
        df_combined = pd.concat([df_combined, df])

for column in df_combined.columns:
    assert not df_combined[column].isna().any()

assert df_combined[DSID_COL].nunique() == df_combined.shape[0]

df_combined.to_csv('./data/all_data.csv', index=False)
